# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/ex5/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
pd.DataFrame(ext_data['train']['features'])
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.141376  0.126192  0.160170  0.039393  0.116594  0.244344  0.364260
# 1     0.139377  0.119569  0.153211  0.039412  0.117448  0.268657  0.362977
# 2     0.163800  0.184355  0.172159  0.027273  0.110422  0.169510  0.386510
# 3     0.143226  0.131679  0.156749  0.038878  0.115537  0.241695  0.368068
# 4     0.137737  0.123774  0.149359  0.042918  0.111843  0.259588  0.368717
# ...        ...       ...       ...       ...       ...       ...       ...
# 6013  0.116490  0.110039  0.161647  0.043416  0.096190  0.239978  0.371168
# 6014  0.125852  0.120752  0.164564  0.039160  0.104617  0.234347  0.369856
# 6015  0.107534  0.116570  0.173803  0.039604  0.088328  0.213753  0.390930
# 6016  0.123527  0.140547  0.164611  0.038327  0.096956  0.192954  0.382039
# 6017  0.118789  0.118466  0.158106  0.043782  0.097575  0.229872  0.372959
#
#           7         8         9     ...      3062      3063      3064  3065  \
# 0     0.179045  0.304383  0.316418  ...  0.000000  0.000000  0.000000   0.0
# 1     0.172853  0.304429  0.321536  ...  0.000558  0.000000  0.000185   0.0
# 2     0.206604  0.313434  0.314130  ...  0.011560  0.000000  0.000000   0.0
# 3     0.185738  0.308175  0.316420  ...  0.000000  0.000457  0.000000   0.0
# 4     0.180469  0.305680  0.309504  ...  0.000000  0.000000  0.000000   0.0
# ...        ...       ...       ...  ...       ...       ...       ...   ...
# 6013  0.168759  0.329152  0.293912  ...  0.000000  0.000000  0.000000   0.0
# 6014  0.180599  0.320280  0.302117  ...  0.001283  0.000000  0.000000   0.0
# 6015  0.170922  0.355653  0.284926  ...  0.000713  0.026625  0.000000   0.0
# 6016  0.200973  0.332633  0.290760  ...  0.002548  0.011003  0.000000   0.0
# 6017  0.169601  0.332104  0.290355  ...  0.000000  0.001279  0.000000   0.0
#
#           3066  3067  3068  3069      3070      3071
# 0     0.011685   0.0   0.0   0.0  0.001349  0.024873
# 1     0.019411   0.0   0.0   0.0  0.010698  0.031158
# 2     0.038945   0.0   0.0   0.0  0.000000  0.005341
# 3     0.005694   0.0   0.0   0.0  0.008102  0.020985
# 4     0.018220   0.0   0.0   0.0  0.003810  0.032367
# ...        ...   ...   ...   ...       ...       ...
# 6013  0.002287   0.0   0.0   0.0  0.000226  0.023715
# 6014  0.000000   0.0   0.0   0.0  0.001988  0.014878
# 6015  0.009445   0.0   0.0   0.0  0.005314  0.000665
# 6016  0.011084   0.0   0.0   0.0  0.004229  0.010059
# 6017  0.011491   0.0   0.0   0.0  0.000270  0.032393
#
# [6018 rows x 3072 columns]

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-4)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
#for machine_type in machine_types:
#    run(machine_type)

# %%
run(machine_types[6])
# Out:
# 2021-05-24 00:16:33,128 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-05-24 00:16:33,129 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-24 00:16:33,178 - 00_train.py - INFO - TRAINING
# 2021-05-24 00:16:35,249 - pytorch_modeler.py - INFO - train
#   0%|          | 0/12 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 12/12 [00:01<00:00, 11.64it/s]
# 2021-05-24 00:16:36,282 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.37it/s]
# 2021-05-24 00:16:36,503 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.06it/s]
#                AUC      pAUC
# Source_0  0.375700  0.473684
# Source_1  0.482500  0.477368
# Source_2  0.392650  0.473684
# Target_0  0.414950  0.481053
# Target_1  0.375300  0.479474
# Target_2  0.424500  0.480526
# mean      0.410933  0.477632
# h_mean    0.407852  0.477612
# 2021-05-24 00:16:37,533 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:157.469031, val_AUC_hmean:0.407852, val_pAUC_hmean:0.477612, best_flag:True
# 2021-05-24 00:16:37,534 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.69it/s]
# 2021-05-24 00:16:37,986 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.92it/s]
# 2021-05-24 00:16:38,212 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.21it/s]
# 2021-05-24 00:16:38,434 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:103.968452, val_AUC_hmean:0.365013, val_pAUC_hmean:0.475427, best_flag:False
# 2021-05-24 00:16:38,435 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.47it/s]
# 2021-05-24 00:16:38,891 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.80it/s]
# 2021-05-24 00:16:39,096 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.74it/s]
#                AUC      pAUC
# Source_0  0.556800  0.493684
# Source_1  0.632800  0.486842
# Source_2  0.512100  0.520526
# Target_0  0.524400  0.510526
# Target_1  0.721600  0.607895
# Target_2  0.654600  0.581579
# mean      0.600383  0.533509
# h_mean    0.591168  0.529847
# 2021-05-24 00:16:40,092 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:88.405804, val_AUC_hmean:0.591168, val_pAUC_hmean:0.529847, best_flag:True
# 2021-05-24 00:16:40,093 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 27.07it/s]
# 2021-05-24 00:16:40,538 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.75it/s]
# 2021-05-24 00:16:40,746 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.65it/s]
#                AUC      pAUC
# Source_0  0.726400  0.560000
# Source_1  0.642200  0.495789
# Source_2  0.766200  0.545789
# Target_0  0.721800  0.608947
# Target_1  0.863100  0.588421
# Target_2  0.832200  0.621053
# mean      0.758650  0.570000
# h_mean    0.751445  0.566748
# 2021-05-24 00:16:41,748 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:80.414757, val_AUC_hmean:0.751445, val_pAUC_hmean:0.566748, best_flag:True
# 2021-05-24 00:16:41,749 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.48it/s]
# 2021-05-24 00:16:42,204 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.29it/s]
# 2021-05-24 00:16:42,419 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
# 2021-05-24 00:16:42,637 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:74.866783, val_AUC_hmean:0.695408, val_pAUC_hmean:0.550279, best_flag:False
# 2021-05-24 00:16:42,638 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.39it/s]
# 2021-05-24 00:16:43,113 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.65it/s]
# 2021-05-24 00:16:43,324 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.55it/s]
# 2021-05-24 00:16:43,541 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:70.745458, val_AUC_hmean:0.598977, val_pAUC_hmean:0.526460, best_flag:False
# 2021-05-24 00:16:43,542 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.67it/s]
# 2021-05-24 00:16:43,995 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.49it/s]
# 2021-05-24 00:16:44,211 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.82it/s]
# 2021-05-24 00:16:44,420 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:67.616251, val_AUC_hmean:0.627517, val_pAUC_hmean:0.514948, best_flag:False
# 2021-05-24 00:16:44,421 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.91it/s]
# 2021-05-24 00:16:44,870 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.48it/s]
# 2021-05-24 00:16:45,103 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.68it/s]
# 2021-05-24 00:16:45,317 - pytorch_modeler.py - INFO - epoch:8/300, train_losses:65.438674, val_AUC_hmean:0.623885, val_pAUC_hmean:0.506121, best_flag:False
# 2021-05-24 00:16:45,318 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.85it/s]
# 2021-05-24 00:16:45,768 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.07it/s]
# 2021-05-24 00:16:45,991 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.17it/s]
# 2021-05-24 00:16:46,213 - pytorch_modeler.py - INFO - epoch:9/300, train_losses:63.684411, val_AUC_hmean:0.652030, val_pAUC_hmean:0.496277, best_flag:False
# 2021-05-24 00:16:46,214 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.74it/s]
# 2021-05-24 00:16:46,683 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.44it/s]
# 2021-05-24 00:16:46,899 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.52it/s]
# 2021-05-24 00:16:47,118 - pytorch_modeler.py - INFO - epoch:10/300, train_losses:62.354646, val_AUC_hmean:0.635526, val_pAUC_hmean:0.497326, best_flag:False
# 2021-05-24 00:16:47,119 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.74it/s]
# 2021-05-24 00:16:47,570 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# 2021-05-24 00:16:47,784 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.75it/s]
# 2021-05-24 00:16:47,996 - pytorch_modeler.py - INFO - epoch:11/300, train_losses:61.294959, val_AUC_hmean:0.636322, val_pAUC_hmean:0.496902, best_flag:False
# 2021-05-24 00:16:47,997 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.55it/s]
# 2021-05-24 00:16:48,451 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.23it/s]
# 2021-05-24 00:16:48,670 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.84it/s]
# 2021-05-24 00:16:48,880 - pytorch_modeler.py - INFO - epoch:12/300, train_losses:60.278866, val_AUC_hmean:0.600880, val_pAUC_hmean:0.502918, best_flag:False
# 2021-05-24 00:16:48,882 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.69it/s]
# 2021-05-24 00:16:49,335 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# 2021-05-24 00:16:49,550 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.44it/s]
# 2021-05-24 00:16:49,771 - pytorch_modeler.py - INFO - epoch:13/300, train_losses:59.592954, val_AUC_hmean:0.595198, val_pAUC_hmean:0.497109, best_flag:False
# 2021-05-24 00:16:49,772 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.36it/s]
# 2021-05-24 00:16:50,230 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.33it/s]
# 2021-05-24 00:16:50,446 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.80it/s]
# 2021-05-24 00:16:50,660 - pytorch_modeler.py - INFO - epoch:14/300, train_losses:58.755704, val_AUC_hmean:0.554312, val_pAUC_hmean:0.499208, best_flag:False
# 2021-05-24 00:16:50,661 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.33it/s]
# 2021-05-24 00:16:51,120 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.96it/s]
# 2021-05-24 00:16:51,341 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.49it/s]
# 2021-05-24 00:16:51,563 - pytorch_modeler.py - INFO - epoch:15/300, train_losses:58.072492, val_AUC_hmean:0.563856, val_pAUC_hmean:0.501216, best_flag:False
# 2021-05-24 00:16:51,564 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.71it/s]
# 2021-05-24 00:16:52,033 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.48it/s]
# 2021-05-24 00:16:52,247 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.68it/s]
# 2021-05-24 00:16:52,462 - pytorch_modeler.py - INFO - epoch:16/300, train_losses:57.606463, val_AUC_hmean:0.568556, val_pAUC_hmean:0.495451, best_flag:False
# 2021-05-24 00:16:52,463 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.41it/s]
# 2021-05-24 00:16:52,920 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.10it/s]
# 2021-05-24 00:16:53,139 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.53it/s]
# 2021-05-24 00:16:53,356 - pytorch_modeler.py - INFO - epoch:17/300, train_losses:56.994950, val_AUC_hmean:0.576253, val_pAUC_hmean:0.500194, best_flag:False
# 2021-05-24 00:16:53,357 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 25.88it/s]
# 2021-05-24 00:16:53,823 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.59it/s]
# 2021-05-24 00:16:54,033 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.09it/s]
# 2021-05-24 00:16:54,257 - pytorch_modeler.py - INFO - epoch:18/300, train_losses:56.740915, val_AUC_hmean:0.572975, val_pAUC_hmean:0.494713, best_flag:False
# 2021-05-24 00:16:54,258 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.69it/s]
# 2021-05-24 00:16:54,710 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.93it/s]
# 2021-05-24 00:16:54,933 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.68it/s]
# 2021-05-24 00:16:55,146 - pytorch_modeler.py - INFO - epoch:19/300, train_losses:56.298541, val_AUC_hmean:0.559048, val_pAUC_hmean:0.497492, best_flag:False
# 2021-05-24 00:16:55,147 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.84it/s]
# 2021-05-24 00:16:55,596 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.03it/s]
# 2021-05-24 00:16:55,817 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.16it/s]
# 2021-05-24 00:16:56,041 - pytorch_modeler.py - INFO - epoch:20/300, train_losses:55.869802, val_AUC_hmean:0.580149, val_pAUC_hmean:0.495676, best_flag:False
# 2021-05-24 00:16:56,042 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.03it/s]
# 2021-05-24 00:16:56,506 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.37it/s]
# 2021-05-24 00:16:56,723 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# 2021-05-24 00:16:56,937 - pytorch_modeler.py - INFO - epoch:21/300, train_losses:55.505986, val_AUC_hmean:0.548617, val_pAUC_hmean:0.494295, best_flag:False
# 2021-05-24 00:16:56,938 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.57it/s]
# 2021-05-24 00:16:57,391 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.12it/s]
# 2021-05-24 00:16:57,611 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.90it/s]
# 2021-05-24 00:16:57,836 - pytorch_modeler.py - INFO - epoch:22/300, train_losses:55.019249, val_AUC_hmean:0.584420, val_pAUC_hmean:0.498355, best_flag:False
# 2021-05-24 00:16:57,837 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.37it/s]
# 2021-05-24 00:16:58,295 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.82it/s]
# 2021-05-24 00:16:58,519 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# 2021-05-24 00:16:58,742 - pytorch_modeler.py - INFO - epoch:23/300, train_losses:54.713806, val_AUC_hmean:0.571926, val_pAUC_hmean:0.502166, best_flag:False
# 2021-05-24 00:16:58,743 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.18it/s]
# 2021-05-24 00:16:59,204 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.31it/s]
# 2021-05-24 00:16:59,419 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.63it/s]
# 2021-05-24 00:16:59,651 - pytorch_modeler.py - INFO - epoch:24/300, train_losses:54.573565, val_AUC_hmean:0.585697, val_pAUC_hmean:0.502949, best_flag:False
# 2021-05-24 00:16:59,652 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 26.20it/s]
# 2021-05-24 00:17:00,113 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.42it/s]
# 2021-05-24 00:17:00,330 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.32it/s]
# 2021-05-24 00:17:00,552 - pytorch_modeler.py - INFO - epoch:25/300, train_losses:54.186402, val_AUC_hmean:0.576431, val_pAUC_hmean:0.499769, best_flag:False
# 2021-05-24 00:17:00,553 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 24.73it/s]
# 2021-05-24 00:17:01,041 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.75it/s]
# 2021-05-24 00:17:01,269 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.72it/s]
# 2021-05-24 00:17:01,499 - pytorch_modeler.py - INFO - epoch:26/300, train_losses:53.771304, val_AUC_hmean:0.589600, val_pAUC_hmean:0.499846, best_flag:False
# 2021-05-24 00:17:01,500 - pytorch_modeler.py - INFO - train
#  58%|█████▊    | 7/12 [00:00<00:00, 19.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-74616055169e> in <module>
# ----> 1 run(machine_types[0])
#
# <ipython-input-10-540674391f48> in run(machine_type)
#      30     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      31     # training
# ---> 32     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      33
#      34     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/ID_Conditional_VAE/CVAE_ex5/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     134                     target_bool = target_bool.to(device)
#     135                     # model
# --> 136                     output_dict = net(input, section_type, target_bool, device)
#     137                     # calc loss
#     138                     loss, x_hat = output_dict['reconst_error'], output_dict['reconstruction']
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/ID_Conditional_VAE/CVAE_ex5/pytorch_model.py in forward(self, input, section_type, target_bool, device)
#     174         #section_type = F.one_hot(section_type, num_classes=self.num_classes)
#     175
# --> 176         z, KLd = self.Bottleneck(x, device)
#     177         # to one-hot
#     178         #if self.training == True:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/ID_Conditional_VAE/CVAE_ex5/pytorch_model.py in forward(self, input, device)
#     129         var = self.fc_var(x)
#     130
# --> 131         KLd = -0.5 * torch.sum(1 + var - mean**2 - torch.exp(var+self.eps), dim=1)
#     132         #print(KLd.shape)
#     133         z = self.sample_z(mean, var, device)
#
# KeyboardInterrupt:

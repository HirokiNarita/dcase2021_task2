# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/ID_Conditional_VAE/CVAE_ex4/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
pd.DataFrame(ext_data['train']['features'])
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.141376  0.126192  0.160170  0.039393  0.116594  0.244344  0.364260
# 1     0.139377  0.119569  0.153211  0.039412  0.117448  0.268657  0.362977
# 2     0.163800  0.184355  0.172159  0.027273  0.110422  0.169510  0.386510
# 3     0.143226  0.131679  0.156749  0.038878  0.115537  0.241695  0.368068
# 4     0.137737  0.123774  0.149359  0.042918  0.111843  0.259588  0.368717
# ...        ...       ...       ...       ...       ...       ...       ...
# 6013  0.116490  0.110039  0.161647  0.043416  0.096190  0.239978  0.371168
# 6014  0.125852  0.120752  0.164564  0.039160  0.104617  0.234347  0.369856
# 6015  0.107534  0.116570  0.173803  0.039604  0.088328  0.213753  0.390930
# 6016  0.123527  0.140547  0.164611  0.038327  0.096956  0.192954  0.382039
# 6017  0.118789  0.118466  0.158106  0.043782  0.097575  0.229872  0.372959
#
#           7         8         9     ...      3062      3063      3064  3065  \
# 0     0.179045  0.304383  0.316418  ...  0.000000  0.000000  0.000000   0.0
# 1     0.172853  0.304429  0.321536  ...  0.000558  0.000000  0.000185   0.0
# 2     0.206604  0.313434  0.314130  ...  0.011560  0.000000  0.000000   0.0
# 3     0.185738  0.308175  0.316420  ...  0.000000  0.000457  0.000000   0.0
# 4     0.180469  0.305680  0.309504  ...  0.000000  0.000000  0.000000   0.0
# ...        ...       ...       ...  ...       ...       ...       ...   ...
# 6013  0.168759  0.329152  0.293912  ...  0.000000  0.000000  0.000000   0.0
# 6014  0.180599  0.320280  0.302117  ...  0.001283  0.000000  0.000000   0.0
# 6015  0.170922  0.355653  0.284926  ...  0.000713  0.026625  0.000000   0.0
# 6016  0.200973  0.332633  0.290760  ...  0.002548  0.011003  0.000000   0.0
# 6017  0.169601  0.332104  0.290355  ...  0.000000  0.001279  0.000000   0.0
#
#           3066  3067  3068  3069      3070      3071
# 0     0.011685   0.0   0.0   0.0  0.001349  0.024873
# 1     0.019411   0.0   0.0   0.0  0.010698  0.031158
# 2     0.038945   0.0   0.0   0.0  0.000000  0.005341
# 3     0.005694   0.0   0.0   0.0  0.008102  0.020985
# 4     0.018220   0.0   0.0   0.0  0.003810  0.032367
# ...        ...   ...   ...   ...       ...       ...
# 6013  0.002287   0.0   0.0   0.0  0.000226  0.023715
# 6014  0.000000   0.0   0.0   0.0  0.001988  0.014878
# 6015  0.009445   0.0   0.0   0.0  0.005314  0.000665
# 6016  0.011084   0.0   0.0   0.0  0.004229  0.010059
# 6017  0.011491   0.0   0.0   0.0  0.000270  0.032393
#
# [6018 rows x 3072 columns]

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
#for machine_type in machine_types:
#    run(machine_type)

# %%
run(machine_types[2])
# Out:
# 2021-05-21 22:00:20,415 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyTrain
# 2021-05-21 22:00:20,416 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-21 22:00:20,459 - 00_train.py - INFO - TRAINING
# 2021-05-21 22:00:22,494 - pytorch_modeler.py - INFO - train
#   0%|          | 0/189 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 189/189 [00:03<00:00, 51.30it/s]
# 2021-05-21 22:00:26,181 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 92.89it/s]
# 2021-05-21 22:00:26,411 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 88.36it/s]
#                AUC      pAUC
# Source_0  0.257900  0.473684
# Source_1  0.337700  0.531053
# Source_2  0.584700  0.483158
# Target_0  0.832000  0.695263
# Target_1  0.409600  0.516842
# Target_2  0.694300  0.588947
# mean      0.519367  0.548158
# h_mean    0.440122  0.538844
# 2021-05-21 22:00:27,535 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:614.490765, val_AUC_hmean:0.440122, val_pAUC_hmean:0.538844, best_flag:True
# 2021-05-21 22:00:27,536 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:03<00:00, 60.35it/s]
# 2021-05-21 22:00:30,669 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 94.14it/s]
# 2021-05-21 22:00:30,892 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 92.75it/s]
# 2021-05-21 22:00:31,121 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:394.002312, val_AUC_hmean:0.425214, val_pAUC_hmean:0.549371, best_flag:False
# 2021-05-21 22:00:31,122 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:03<00:00, 62.92it/s]
# 2021-05-21 22:00:34,128 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 97.54it/s]
# 2021-05-21 22:00:34,348 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 95.99it/s]
# 2021-05-21 22:00:34,571 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:293.426216, val_AUC_hmean:0.374818, val_pAUC_hmean:0.486570, best_flag:False
# 2021-05-21 22:00:34,572 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:02<00:00, 63.40it/s]
# 2021-05-21 22:00:37,555 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 83.22it/s]
# 2021-05-21 22:00:37,804 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 87.69it/s]
#                AUC      pAUC
# Source_0  0.524900  0.534737
# Source_1  0.519700  0.533684
# Source_2  0.465400  0.498947
# Target_0  0.408000  0.497895
# Target_1  0.546100  0.605789
# Target_2  0.701600  0.594211
# mean      0.527617  0.544211
# h_mean    0.513459  0.541020
# 2021-05-21 22:00:38,844 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:221.632393, val_AUC_hmean:0.513459, val_pAUC_hmean:0.541020, best_flag:True
# 2021-05-21 22:00:38,845 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:03<00:00, 62.66it/s]
# 2021-05-21 22:00:41,863 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 91.74it/s]
# 2021-05-21 22:00:42,092 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 95.67it/s]
# 2021-05-21 22:00:42,318 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:167.123302, val_AUC_hmean:0.443337, val_pAUC_hmean:0.530896, best_flag:False
# 2021-05-21 22:00:42,319 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:02<00:00, 63.29it/s]
# 2021-05-21 22:00:45,307 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 92.00it/s]
# 2021-05-21 22:00:45,536 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 92.42it/s]
# 2021-05-21 22:00:45,767 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:129.333921, val_AUC_hmean:0.344034, val_pAUC_hmean:0.513459, best_flag:False
# 2021-05-21 22:00:45,768 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [00:03<00:00, 62.56it/s]
# 2021-05-21 22:00:48,792 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:00<00:00, 93.00it/s]
# 2021-05-21 22:00:49,018 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:00<00:00, 95.09it/s]
# 2021-05-21 22:00:49,243 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:101.389470, val_AUC_hmean:0.406935, val_pAUC_hmean:0.525009, best_flag:False
# 2021-05-21 22:00:49,244 - pytorch_modeler.py - INFO - train
#  76%|███████▌  | 144/189 [00:02<00:00, 59.49it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-25b7b97ae079> in <module>
# ----> 1 run(machine_types[3])
#
# <ipython-input-10-bb58d9782254> in run(machine_type)
#      30     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      31     # training
# ---> 32     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      33
#      34     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/ID_Conditional_VAE/CVAE_ex4/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     141                     optimizer.step()
#     142                     #scheduler.step()
# --> 143                     tr_losses += loss.item()
#     144                 tr_losses = tr_losses / len(dataloaders_dict[phase])
#     145                 # tensorboard
#
# KeyboardInterrupt:

# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/ex4_revised/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
plt.figure(figsize=(20,3))
plt.plot(ext_data['train']['features'][0])

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
for machine_type in machine_types:
    run(machine_type)

# %%
#run(machine_types[1])
# Out:
# 2021-05-23 23:31:14,874 - 00_train.py - INFO - TARGET MACHINE_TYPE: gearbox
# 2021-05-23 23:31:14,875 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-23 23:31:14,932 - 00_train.py - INFO - TRAINING
# 2021-05-23 23:31:17,045 - pytorch_modeler.py - INFO - train
#   0%|          | 0/12 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 12/12 [00:01<00:00, 10.95it/s]
# 2021-05-23 23:31:18,145 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.32it/s]
# 2021-05-23 23:31:18,354 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.41it/s]
#                AUC      pAUC
# Source_0  0.667985  0.544502
# Source_1  0.421211  0.485416
# Source_2  0.565955  0.545654
# Target_0  0.843171  0.539169
# Target_1  0.301440  0.474948
# Target_2  0.616905  0.564745
# mean      0.569445  0.525739
# h_mean    0.510097  0.523551
# 2021-05-23 23:31:19,759 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:2235.376444, val_AUC_hmean:0.510097, val_pAUC_hmean:0.523551, best_flag:True
# 2021-05-23 23:31:19,761 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.93it/s]
# 2021-05-23 23:31:20,311 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.87it/s]
# 2021-05-23 23:31:20,538 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.50it/s]
#                AUC      pAUC
# Source_0  0.720537  0.585759
# Source_1  0.652606  0.486770
# Source_2  0.630972  0.530257
# Target_0  0.863715  0.578054
# Target_1  0.569702  0.481536
# Target_2  0.675714  0.572682
# mean      0.685541  0.539176
# h_mean    0.674306  0.535703
# 2021-05-23 23:31:21,829 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:1731.804047, val_AUC_hmean:0.674306, val_pAUC_hmean:0.535703, best_flag:True
# 2021-05-23 23:31:21,830 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.23it/s]
# 2021-05-23 23:31:22,397 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.29it/s]
# 2021-05-23 23:31:22,614 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.28it/s]
#                AUC      pAUC
# Source_0  0.725958  0.546430
# Source_1  0.783608  0.576926
# Source_2  0.682032  0.597424
# Target_0  0.776620  0.561302
# Target_1  0.748371  0.567811
# Target_2  0.731825  0.571220
# mean      0.741402  0.570185
# h_mean    0.739813  0.569768
# 2021-05-23 23:31:23,914 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:1550.208374, val_AUC_hmean:0.739813, val_pAUC_hmean:0.569768, best_flag:True
# 2021-05-23 23:31:23,915 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.51it/s]
# 2021-05-23 23:31:24,451 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.36it/s]
# 2021-05-23 23:31:24,653 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.44it/s]
# 2021-05-23 23:31:24,874 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:1431.674937, val_AUC_hmean:0.687855, val_pAUC_hmean:0.564810, best_flag:False
# 2021-05-23 23:31:24,875 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.85it/s]
# 2021-05-23 23:31:25,427 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.01it/s]
# 2021-05-23 23:31:25,677 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.64it/s]
#                AUC      pAUC
# Source_0  0.748718  0.560697
# Source_1  0.880916  0.748574
# Source_2  0.643250  0.551869
# Target_0  0.763214  0.591455
# Target_1  0.868827  0.700383
# Target_2  0.651270  0.540100
# mean      0.759366  0.615513
# h_mean    0.747935  0.605973
# 2021-05-23 23:31:27,020 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:1364.580658, val_AUC_hmean:0.747935, val_pAUC_hmean:0.605973, best_flag:True
# 2021-05-23 23:31:27,021 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.85it/s]
# 2021-05-23 23:31:27,548 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.47it/s]
# 2021-05-23 23:31:27,765 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.28it/s]
# 2021-05-23 23:31:27,968 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:1303.044637, val_AUC_hmean:0.697932, val_pAUC_hmean:0.554518, best_flag:False
# 2021-05-23 23:31:27,969 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.86it/s]
# 2021-05-23 23:31:28,497 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.83it/s]
# 2021-05-23 23:31:28,708 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.16it/s]
#                AUC      pAUC
# Source_0  0.795165  0.635370
# Source_1  0.924811  0.860118
# Source_2  0.515566  0.524960
# Target_0  0.834973  0.620289
# Target_1  0.919753  0.770775
# Target_2  0.498413  0.485798
# mean      0.748114  0.649552
# h_mean    0.700135  0.624386
# 2021-05-23 23:31:30,015 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:1250.388763, val_AUC_hmean:0.700135, val_pAUC_hmean:0.624386, best_flag:True
# 2021-05-23 23:31:30,016 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.02it/s]
# 2021-05-23 23:31:30,539 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.04it/s]
# 2021-05-23 23:31:30,745 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.09it/s]
# 2021-05-23 23:31:30,951 - pytorch_modeler.py - INFO - epoch:8/300, train_losses:1199.439524, val_AUC_hmean:0.707894, val_pAUC_hmean:0.609166, best_flag:False
# 2021-05-23 23:31:30,952 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.01it/s]
# 2021-05-23 23:31:31,476 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.93it/s]
# 2021-05-23 23:31:31,683 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.30it/s]
#                AUC      pAUC
# Source_0  0.799560  0.657220
# Source_1  0.898748  0.808046
# Source_2  0.602120  0.526655
# Target_0  0.800058  0.598562
# Target_1  0.890689  0.777543
# Target_2  0.595556  0.524854
# mean      0.764455  0.648813
# h_mean    0.742953  0.630255
# 2021-05-23 23:31:32,946 - pytorch_modeler.py - INFO - epoch:9/300, train_losses:1170.764425, val_AUC_hmean:0.742953, val_pAUC_hmean:0.630255, best_flag:True
# 2021-05-23 23:31:32,947 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.12it/s]
# 2021-05-23 23:31:33,468 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.68it/s]
# 2021-05-23 23:31:33,682 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# 2021-05-23 23:31:33,892 - pytorch_modeler.py - INFO - epoch:10/300, train_losses:1137.684784, val_AUC_hmean:0.732615, val_pAUC_hmean:0.629531, best_flag:False
# 2021-05-23 23:31:33,893 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.48it/s]
# 2021-05-23 23:31:34,429 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.33it/s]
# 2021-05-23 23:31:34,656 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.84it/s]
# 2021-05-23 23:31:34,886 - pytorch_modeler.py - INFO - epoch:11/300, train_losses:1104.532003, val_AUC_hmean:0.728498, val_pAUC_hmean:0.607666, best_flag:False
# 2021-05-23 23:31:34,887 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.74it/s]
# 2021-05-23 23:31:35,417 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.55it/s]
# 2021-05-23 23:31:35,632 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.37it/s]
# 2021-05-23 23:31:35,833 - pytorch_modeler.py - INFO - epoch:12/300, train_losses:1064.099497, val_AUC_hmean:0.725624, val_pAUC_hmean:0.577256, best_flag:False
# 2021-05-23 23:31:35,834 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.80it/s]
# 2021-05-23 23:31:36,387 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.10it/s]
# 2021-05-23 23:31:36,632 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.35it/s]
# 2021-05-23 23:31:36,837 - pytorch_modeler.py - INFO - epoch:13/300, train_losses:1042.483088, val_AUC_hmean:0.733663, val_pAUC_hmean:0.581602, best_flag:False
# 2021-05-23 23:31:36,838 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.90it/s]
# 2021-05-23 23:31:37,365 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.05it/s]
# 2021-05-23 23:31:37,574 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.21it/s]
# 2021-05-23 23:31:37,779 - pytorch_modeler.py - INFO - epoch:14/300, train_losses:1021.597951, val_AUC_hmean:0.715191, val_pAUC_hmean:0.603512, best_flag:False
# 2021-05-23 23:31:37,781 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.82it/s]
# 2021-05-23 23:31:38,309 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.48it/s]
# 2021-05-23 23:31:38,525 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.44it/s]
# 2021-05-23 23:31:38,726 - pytorch_modeler.py - INFO - epoch:15/300, train_losses:981.476624, val_AUC_hmean:0.732397, val_pAUC_hmean:0.600627, best_flag:False
# 2021-05-23 23:31:38,727 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.35it/s]
# 2021-05-23 23:31:39,244 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.37it/s]
# 2021-05-23 23:31:39,461 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.49it/s]
# 2021-05-23 23:31:39,660 - pytorch_modeler.py - INFO - epoch:16/300, train_losses:958.672658, val_AUC_hmean:0.728269, val_pAUC_hmean:0.617828, best_flag:False
# 2021-05-23 23:31:39,662 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.00it/s]
# 2021-05-23 23:31:40,210 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
# 2021-05-23 23:31:40,418 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.97it/s]
# 2021-05-23 23:31:40,647 - pytorch_modeler.py - INFO - epoch:17/300, train_losses:938.442663, val_AUC_hmean:0.680508, val_pAUC_hmean:0.625864, best_flag:False
# 2021-05-23 23:31:40,648 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.65it/s]
# 2021-05-23 23:31:41,205 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.02it/s]
# 2021-05-23 23:31:41,430 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.73it/s]
# 2021-05-23 23:31:41,644 - pytorch_modeler.py - INFO - epoch:18/300, train_losses:916.867396, val_AUC_hmean:0.706369, val_pAUC_hmean:0.617010, best_flag:False
# 2021-05-23 23:31:41,645 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.97it/s]
# 2021-05-23 23:31:42,170 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.57it/s]
# 2021-05-23 23:31:42,383 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.71it/s]
# 2021-05-23 23:31:42,597 - pytorch_modeler.py - INFO - epoch:19/300, train_losses:893.919856, val_AUC_hmean:0.730033, val_pAUC_hmean:0.575736, best_flag:False
# 2021-05-23 23:31:42,598 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.42it/s]
# 2021-05-23 23:31:43,161 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.57it/s]
# 2021-05-23 23:31:43,376 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.11it/s]
# 2021-05-23 23:31:43,583 - pytorch_modeler.py - INFO - epoch:20/300, train_losses:873.417114, val_AUC_hmean:0.709018, val_pAUC_hmean:0.601929, best_flag:False
# 2021-05-23 23:31:43,584 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.04it/s]
# 2021-05-23 23:31:44,130 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.70it/s]
# 2021-05-23 23:31:44,367 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.07it/s]
# 2021-05-23 23:31:44,594 - pytorch_modeler.py - INFO - epoch:21/300, train_losses:853.244202, val_AUC_hmean:0.722503, val_pAUC_hmean:0.614649, best_flag:False
# 2021-05-23 23:31:44,595 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 20.53it/s]
# 2021-05-23 23:31:45,182 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  8.99it/s]
# 2021-05-23 23:31:45,435 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# 2021-05-23 23:31:45,644 - pytorch_modeler.py - INFO - epoch:22/300, train_losses:840.143112, val_AUC_hmean:0.747841, val_pAUC_hmean:0.596810, best_flag:False
# 2021-05-23 23:31:45,645 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.70it/s]
# 2021-05-23 23:31:46,176 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.80it/s]
# 2021-05-23 23:31:46,386 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.20it/s]
# 2021-05-23 23:31:46,589 - pytorch_modeler.py - INFO - epoch:23/300, train_losses:822.953115, val_AUC_hmean:0.755029, val_pAUC_hmean:0.611555, best_flag:False
# 2021-05-23 23:31:46,590 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.42it/s]
# 2021-05-23 23:31:47,127 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.29it/s]
# 2021-05-23 23:31:47,348 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.12it/s]
# 2021-05-23 23:31:47,556 - pytorch_modeler.py - INFO - epoch:24/300, train_losses:795.038925, val_AUC_hmean:0.701376, val_pAUC_hmean:0.614886, best_flag:False
# 2021-05-23 23:31:47,558 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.15it/s]
# 2021-05-23 23:31:48,079 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.24it/s]
# 2021-05-23 23:31:48,299 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00,  9.97it/s]
# 2021-05-23 23:31:48,527 - pytorch_modeler.py - INFO - epoch:25/300, train_losses:784.020930, val_AUC_hmean:0.728626, val_pAUC_hmean:0.568254, best_flag:False
# 2021-05-23 23:31:48,528 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.23it/s]
# 2021-05-23 23:31:49,070 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.38it/s]
# 2021-05-23 23:31:49,287 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.22it/s]
# 2021-05-23 23:31:49,490 - pytorch_modeler.py - INFO - epoch:26/300, train_losses:763.087229, val_AUC_hmean:0.707497, val_pAUC_hmean:0.596421, best_flag:False
# 2021-05-23 23:31:49,492 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.94it/s]
# 2021-05-23 23:31:50,017 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.77it/s]
# 2021-05-23 23:31:50,230 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.11it/s]
# 2021-05-23 23:31:50,436 - pytorch_modeler.py - INFO - epoch:27/300, train_losses:745.229319, val_AUC_hmean:0.732287, val_pAUC_hmean:0.593191, best_flag:False
# 2021-05-23 23:31:50,438 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.50it/s]
# 2021-05-23 23:31:50,973 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.00it/s]
# 2021-05-23 23:31:51,182 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.40it/s]
# 2021-05-23 23:31:51,387 - pytorch_modeler.py - INFO - epoch:28/300, train_losses:724.955953, val_AUC_hmean:0.737101, val_pAUC_hmean:0.580508, best_flag:False
# 2021-05-23 23:31:51,388 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.84it/s]
# 2021-05-23 23:31:51,916 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.54it/s]
# 2021-05-23 23:31:52,133 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.23it/s]
# 2021-05-23 23:31:52,336 - pytorch_modeler.py - INFO - epoch:29/300, train_losses:715.867793, val_AUC_hmean:0.764976, val_pAUC_hmean:0.586654, best_flag:False
# 2021-05-23 23:31:52,337 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.93it/s]
# 2021-05-23 23:31:52,862 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.94it/s]
# 2021-05-23 23:31:53,068 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# 2021-05-23 23:31:53,274 - pytorch_modeler.py - INFO - epoch:30/300, train_losses:702.591365, val_AUC_hmean:0.701698, val_pAUC_hmean:0.595304, best_flag:False
# 2021-05-23 23:31:53,275 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.94it/s]
# 2021-05-23 23:31:53,800 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# 2021-05-23 23:31:54,008 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.20it/s]
# 2021-05-23 23:31:54,212 - pytorch_modeler.py - INFO - epoch:31/300, train_losses:693.952972, val_AUC_hmean:0.711940, val_pAUC_hmean:0.599305, best_flag:False
# 2021-05-23 23:31:54,214 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.18it/s]
# 2021-05-23 23:31:54,734 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.48it/s]
# 2021-05-23 23:31:54,951 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.17it/s]
# 2021-05-23 23:31:55,156 - pytorch_modeler.py - INFO - epoch:32/300, train_losses:679.283183, val_AUC_hmean:0.728103, val_pAUC_hmean:0.596149, best_flag:False
# 2021-05-23 23:31:55,157 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.80it/s]
# 2021-05-23 23:31:55,685 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.01it/s]
# 2021-05-23 23:31:55,891 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.60it/s]
# 2021-05-23 23:31:56,107 - pytorch_modeler.py - INFO - epoch:33/300, train_losses:662.775543, val_AUC_hmean:0.681561, val_pAUC_hmean:0.568062, best_flag:False
# 2021-05-23 23:31:56,108 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.31it/s]
# 2021-05-23 23:31:56,648 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.91it/s]
# 2021-05-23 23:31:56,855 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.22it/s]
# 2021-05-23 23:31:57,061 - pytorch_modeler.py - INFO - epoch:34/300, train_losses:644.757334, val_AUC_hmean:0.701457, val_pAUC_hmean:0.602719, best_flag:False
# 2021-05-23 23:31:57,062 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.97it/s]
# 2021-05-23 23:31:57,586 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 11.02it/s]
# 2021-05-23 23:31:57,792 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.16it/s]
# 2021-05-23 23:31:57,998 - pytorch_modeler.py - INFO - epoch:35/300, train_losses:631.408712, val_AUC_hmean:0.708563, val_pAUC_hmean:0.588528, best_flag:False
# 2021-05-23 23:31:57,999 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.40it/s]
# 2021-05-23 23:31:58,537 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.78it/s]
# 2021-05-23 23:31:58,750 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.04it/s]
# 2021-05-23 23:31:58,956 - pytorch_modeler.py - INFO - epoch:36/300, train_losses:616.702072, val_AUC_hmean:0.706936, val_pAUC_hmean:0.583504, best_flag:False
# 2021-05-23 23:31:58,958 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.06it/s]
# 2021-05-23 23:31:59,480 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.56it/s]
# 2021-05-23 23:31:59,694 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.00it/s]
# 2021-05-23 23:31:59,903 - pytorch_modeler.py - INFO - epoch:37/300, train_losses:604.231191, val_AUC_hmean:0.715054, val_pAUC_hmean:0.595417, best_flag:False
# 2021-05-23 23:31:59,904 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.69it/s]
# 2021-05-23 23:32:00,436 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.90it/s]
# 2021-05-23 23:32:00,644 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.97it/s]
# 2021-05-23 23:32:00,857 - pytorch_modeler.py - INFO - epoch:38/300, train_losses:596.394933, val_AUC_hmean:0.714960, val_pAUC_hmean:0.597764, best_flag:False
# 2021-05-23 23:32:00,858 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.57it/s]
# 2021-05-23 23:32:01,392 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.85it/s]
# 2021-05-23 23:32:01,623 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.27it/s]
# 2021-05-23 23:32:01,845 - pytorch_modeler.py - INFO - epoch:39/300, train_losses:584.822235, val_AUC_hmean:0.715619, val_pAUC_hmean:0.594833, best_flag:False
# 2021-05-23 23:32:01,847 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.72it/s]
# 2021-05-23 23:32:02,402 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00,  9.45it/s]
# 2021-05-23 23:32:02,638 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.87it/s]
# 2021-05-23 23:32:02,853 - pytorch_modeler.py - INFO - epoch:40/300, train_losses:573.055059, val_AUC_hmean:0.712192, val_pAUC_hmean:0.575680, best_flag:False
# 2021-05-23 23:32:02,854 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.75it/s]
# 2021-05-23 23:32:03,385 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.11it/s]
# 2021-05-23 23:32:03,609 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.54it/s]
# 2021-05-23 23:32:03,828 - pytorch_modeler.py - INFO - epoch:41/300, train_losses:562.305832, val_AUC_hmean:0.745683, val_pAUC_hmean:0.580892, best_flag:False
# 2021-05-23 23:32:03,829 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.67it/s]
# 2021-05-23 23:32:04,385 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.58it/s]
# 2021-05-23 23:32:04,605 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.43it/s]
# 2021-05-23 23:32:04,827 - pytorch_modeler.py - INFO - epoch:42/300, train_losses:552.550822, val_AUC_hmean:0.746161, val_pAUC_hmean:0.579180, best_flag:False
# 2021-05-23 23:32:04,828 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.14it/s]
# 2021-05-23 23:32:05,373 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.76it/s]
# 2021-05-23 23:32:05,585 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 11.03it/s]
# 2021-05-23 23:32:05,795 - pytorch_modeler.py - INFO - epoch:43/300, train_losses:538.784490, val_AUC_hmean:0.745267, val_pAUC_hmean:0.584103, best_flag:False
# 2021-05-23 23:32:05,796 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.92it/s]
# 2021-05-23 23:32:06,346 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.89it/s]
# 2021-05-23 23:32:06,557 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.31it/s]
# 2021-05-23 23:32:06,776 - pytorch_modeler.py - INFO - epoch:44/300, train_losses:531.152349, val_AUC_hmean:0.710783, val_pAUC_hmean:0.604579, best_flag:False
# 2021-05-23 23:32:06,778 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 21.52it/s]
# 2021-05-23 23:32:07,338 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.69it/s]
# 2021-05-23 23:32:07,550 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 10.61it/s]
# 2021-05-23 23:32:07,768 - pytorch_modeler.py - INFO - epoch:45/300, train_losses:520.763367, val_AUC_hmean:0.675592, val_pAUC_hmean:0.603401, best_flag:False
# 2021-05-23 23:32:07,769 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.23it/s]
# 2021-05-23 23:32:08,312 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 10.86it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ccabc866b6c0> in <module>
# ----> 1 run(machine_types[1])
#
# <ipython-input-10-bb58d9782254> in run(machine_type)
#      30     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      31     # training
# ---> 32     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      33
#      34     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/ID_Conditional_VAE/CVAE_ex4_revised/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     154                 inputs = []
#     155                 x_hats = []
# --> 156                 for sample in tqdm(dataloaders_dict[phase]):
#     157                     # feature
#     158                     input = sample['features']
#
# ~/anaconda3/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1169                 # no valid `self._rcvd_idx` is found (i.e., didn't break)
#    1170                 if not self._persistent_workers:
# -> 1171                     self._shutdown_workers()
#    1172                 raise StopIteration
#    1173
#
# ~/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _shutdown_workers(self)
#    1295                     # wrong, we set a timeout and if the workers fail to join,
#    1296                     # they are killed in the `finally` block.
# -> 1297                     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#    1298                 for q in self._index_queues:
#    1299                     q.cancel_join_thread()
#
# ~/anaconda3/lib/python3.8/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# ~/anaconda3/lib/python3.8/multiprocessing/popen_fork.py in wait(self, timeout)
#      42             if timeout is not None:
#      43                 from multiprocessing.connection import wait
# ---> 44                 if not wait([self.sentinel], timeout):
#      45                     return None
#      46             # This shouldn't block if wait() returned successfully.
#
# ~/anaconda3/lib/python3.8/multiprocessing/connection.py in wait(object_list, timeout)
#     929
#     930             while True:
# --> 931                 ready = selector.select(timeout)
#     932                 if ready:
#     933                     return [key.fileobj for (key, events) in ready]
#
# ~/anaconda3/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

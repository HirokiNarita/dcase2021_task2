# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import ResNet38 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CNN_finetune/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # model out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    net = Model(sample_rate=config['param']['sample_rate'],
                window_size=config['param']['window_size'],
                hop_size=config['param']['hop_size'],
                mel_bins=config['param']['mel_bins'],
                fmin=config['param']['fmin'],
                fmax=config['param']['fmax'],
                classes_num=6
                )
    optimizer = optim.Adam(net.parameters())
    criterion = nn.CrossEntropyLoss()
    num_epochs = config['param']['num_epochs']
    scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e2, 
                                              max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # load pre-trained model
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])
    net.load_state_dict(pretrained_dict['model'], strict=False)
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, criterion, scheduler, num_epochs, writer, model_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
for machine_type in machine_types[4:]:
    run(machine_type, dev_paths)
# Out:
# 2021-04-09 09:10:12,399 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-04-09 09:10:12,401 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-04-09 09:10:12,403 - 00_train.py - INFO - TRAINING
# 2021-04-09 09:10:16,043 - pytorch_modeler.py - INFO - train
#   0%|          | 0/189 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 189/189 [03:43<00:00,  1.18s/it]
# 2021-04-09 09:13:59,520 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:08<00:00,  2.16it/s]
# 2021-04-09 09:14:10,831 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 09:14:10,846 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:08<00:00,  2.37it/s]
# 2021-04-09 09:14:18,851 - pytorch_modeler.py - INFO - epoch:1/40, train_losses:25.133854746818542, val_source_losses:1.437139, val_target_losses:1.322834, best_flag:True
# 2021-04-09 09:14:18,852 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:43<00:00,  1.18s/it]
# 2021-04-09 09:18:02,081 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.67it/s]
# 2021-04-09 09:18:11,741 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 09:18:11,758 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.51it/s]
# 2021-04-09 09:18:19,323 - pytorch_modeler.py - INFO - epoch:2/40, train_losses:17.61351203918457, val_source_losses:0.942206, val_target_losses:0.927027, best_flag:True
# 2021-04-09 09:18:19,324 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:52<00:00,  1.23s/it]
# 2021-04-09 09:22:11,560 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
# 2021-04-09 09:22:18,589 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.39it/s]
# 2021-04-09 09:22:26,547 - pytorch_modeler.py - INFO - epoch:3/40, train_losses:23.220008470118046, val_source_losses:1.161325, val_target_losses:1.222106, best_flag:False
# 2021-04-09 09:22:26,548 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:29<00:00,  1.11s/it]
# 2021-04-09 09:25:55,733 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.74it/s]
# 2021-04-09 09:26:02,678 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.74it/s]
# 2021-04-09 09:26:09,604 - pytorch_modeler.py - INFO - epoch:4/40, train_losses:15.60498632537201, val_source_losses:0.961371, val_target_losses:0.821315, best_flag:False
# 2021-04-09 09:26:09,605 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:29<00:00,  1.11s/it]
# 2021-04-09 09:29:39,172 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.73it/s]
# 2021-04-09 09:29:48,629 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 09:29:48,630 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.73it/s]
# 2021-04-09 09:29:55,602 - pytorch_modeler.py - INFO - epoch:5/40, train_losses:9.393164291977882, val_source_losses:0.811228, val_target_losses:0.494377, best_flag:True
# 2021-04-09 09:29:55,603 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:27<00:00,  1.10s/it]
# 2021-04-09 09:33:23,071 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 09:33:32,439 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 09:33:32,440 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 09:33:39,319 - pytorch_modeler.py - INFO - epoch:6/40, train_losses:7.554466133005917, val_source_losses:0.566249, val_target_losses:0.397603, best_flag:True
# 2021-04-09 09:33:39,320 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:27<00:00,  1.10s/it]
# 2021-04-09 09:37:07,009 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 09:37:13,904 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 09:37:20,803 - pytorch_modeler.py - INFO - epoch:7/40, train_losses:13.585160315036774, val_source_losses:0.631355, val_target_losses:0.715008, best_flag:False
# 2021-04-09 09:37:20,804 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:27<00:00,  1.10s/it]
# 2021-04-09 09:40:48,138 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.73it/s]
# 2021-04-09 09:40:55,096 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.75it/s]
# 2021-04-09 09:41:02,016 - pytorch_modeler.py - INFO - epoch:8/40, train_losses:11.671242129057646, val_source_losses:0.802967, val_target_losses:0.614276, best_flag:False
# 2021-04-09 09:41:02,017 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.09s/it]
# 2021-04-09 09:44:27,823 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 09:44:34,633 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 09:44:41,410 - pytorch_modeler.py - INFO - epoch:9/40, train_losses:14.20857384800911, val_source_losses:0.880088, val_target_losses:0.747820, best_flag:False
# 2021-04-09 09:44:41,411 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 09:48:06,133 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 09:48:12,908 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 09:48:19,691 - pytorch_modeler.py - INFO - epoch:10/40, train_losses:9.182980839177617, val_source_losses:0.822745, val_target_losses:0.483315, best_flag:False
# 2021-04-09 09:48:19,692 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 09:51:44,316 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 09:51:51,091 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 09:51:57,902 - pytorch_modeler.py - INFO - epoch:11/40, train_losses:8.361492987722158, val_source_losses:0.749124, val_target_losses:0.440079, best_flag:False
# 2021-04-09 09:51:57,902 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 09:55:22,598 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 09:55:29,366 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 09:55:36,163 - pytorch_modeler.py - INFO - epoch:12/40, train_losses:10.212469512596726, val_source_losses:0.826455, val_target_losses:0.537498, best_flag:False
# 2021-04-09 09:55:36,164 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:31<00:00,  1.12s/it]
# 2021-04-09 09:59:07,503 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.71it/s]
# 2021-04-09 09:59:14,526 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.75it/s]
# 2021-04-09 09:59:21,438 - pytorch_modeler.py - INFO - epoch:13/40, train_losses:9.126987158320844, val_source_losses:0.794496, val_target_losses:0.480368, best_flag:False
# 2021-04-09 09:59:21,439 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:26<00:00,  1.09s/it]
# 2021-04-09 10:02:47,766 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.75it/s]
# 2021-04-09 10:02:54,685 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.77it/s]
# 2021-04-09 10:03:01,550 - pytorch_modeler.py - INFO - epoch:14/40, train_losses:10.329276636242867, val_source_losses:0.720239, val_target_losses:0.543646, best_flag:False
# 2021-04-09 10:03:01,551 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:26<00:00,  1.09s/it]
# 2021-04-09 10:06:27,628 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 10:06:34,406 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:06:41,180 - pytorch_modeler.py - INFO - epoch:15/40, train_losses:9.562790781259537, val_source_losses:0.737812, val_target_losses:0.503305, best_flag:False
# 2021-04-09 10:06:41,181 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:10:05,935 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 10:10:12,714 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:10:19,488 - pytorch_modeler.py - INFO - epoch:16/40, train_losses:7.291762966196984, val_source_losses:0.853144, val_target_losses:0.383777, best_flag:False
# 2021-04-09 10:10:19,489 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:13:43,847 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:13:50,611 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:13:57,378 - pytorch_modeler.py - INFO - epoch:17/40, train_losses:9.398371011018753, val_source_losses:0.874661, val_target_losses:0.494651, best_flag:False
# 2021-04-09 10:13:57,379 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:17:21,774 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:17:28,548 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:17:35,311 - pytorch_modeler.py - INFO - epoch:18/40, train_losses:8.035976657643914, val_source_losses:0.982023, val_target_losses:0.422946, best_flag:False
# 2021-04-09 10:17:35,312 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:20:59,792 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 10:21:06,573 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:21:13,341 - pytorch_modeler.py - INFO - epoch:19/40, train_losses:11.886227503418922, val_source_losses:0.907124, val_target_losses:0.625591, best_flag:False
# 2021-04-09 10:21:13,342 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:24:37,889 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:24:44,662 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:24:51,428 - pytorch_modeler.py - INFO - epoch:20/40, train_losses:7.481077623553574, val_source_losses:0.698683, val_target_losses:0.393741, best_flag:False
# 2021-04-09 10:24:51,429 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:31<00:00,  1.12s/it]
# 2021-04-09 10:28:22,495 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.75it/s]
# 2021-04-09 10:28:29,403 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
# 2021-04-09 10:28:36,433 - pytorch_modeler.py - INFO - epoch:21/40, train_losses:8.566056186333299, val_source_losses:1.153615, val_target_losses:0.450845, best_flag:False
# 2021-04-09 10:28:36,434 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:34<00:00,  1.13s/it]
# 2021-04-09 10:32:10,568 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.46it/s]
# 2021-04-09 10:32:18,286 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.65it/s]
# 2021-04-09 10:32:25,465 - pytorch_modeler.py - INFO - epoch:22/40, train_losses:10.156286999583244, val_source_losses:1.093910, val_target_losses:0.534541, best_flag:False
# 2021-04-09 10:32:25,466 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:35<00:00,  1.14s/it]
# 2021-04-09 10:36:01,031 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 10:36:07,925 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.62it/s]
# 2021-04-09 10:36:15,185 - pytorch_modeler.py - INFO - epoch:23/40, train_losses:6.110557459294796, val_source_losses:0.866078, val_target_losses:0.321608, best_flag:False
# 2021-04-09 10:36:15,185 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:28<00:00,  1.10s/it]
# 2021-04-09 10:39:43,551 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.77it/s]
# 2021-04-09 10:39:50,412 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.76it/s]
# 2021-04-09 10:39:57,287 - pytorch_modeler.py - INFO - epoch:24/40, train_losses:7.577472650911659, val_source_losses:0.780622, val_target_losses:0.398814, best_flag:False
# 2021-04-09 10:39:57,288 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:26<00:00,  1.09s/it]
# 2021-04-09 10:43:23,690 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:43:30,465 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 10:43:37,256 - pytorch_modeler.py - INFO - epoch:25/40, train_losses:7.10657021519728, val_source_losses:0.681661, val_target_losses:0.374030, best_flag:False
# 2021-04-09 10:43:37,257 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 10:47:02,001 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 10:47:08,780 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.81it/s]
# 2021-04-09 10:47:15,557 - pytorch_modeler.py - INFO - epoch:26/40, train_losses:8.21445559617132, val_source_losses:0.896445, val_target_losses:0.432340, best_flag:False
# 2021-04-09 10:47:15,558 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:37<00:00,  1.15s/it]
# 2021-04-09 10:50:53,230 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:08<00:00,  2.26it/s]
# 2021-04-09 10:51:01,636 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.48it/s]
# 2021-04-09 10:51:09,299 - pytorch_modeler.py - INFO - epoch:27/40, train_losses:6.122856538451742, val_source_losses:0.804381, val_target_losses:0.322256, best_flag:False
# 2021-04-09 10:51:09,301 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:57<00:00,  1.25s/it]
# 2021-04-09 10:55:06,365 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
# 2021-04-09 10:55:13,394 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
# 2021-04-09 10:55:20,424 - pytorch_modeler.py - INFO - epoch:28/40, train_losses:7.966255849227309, val_source_losses:0.778798, val_target_losses:0.419277, best_flag:False
# 2021-04-09 10:55:20,425 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:30<00:00,  1.11s/it]
# 2021-04-09 10:58:50,691 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:07<00:00,  2.68it/s]
# 2021-04-09 10:58:57,781 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.71it/s]
# 2021-04-09 10:59:04,802 - pytorch_modeler.py - INFO - epoch:29/40, train_losses:6.929307088750647, val_source_losses:0.935642, val_target_losses:0.364700, best_flag:False
# 2021-04-09 10:59:04,803 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:29<00:00,  1.11s/it]
# 2021-04-09 11:02:34,437 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:02:41,230 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:02:48,021 - pytorch_modeler.py - INFO - epoch:30/40, train_losses:6.098434855113737, val_source_losses:0.778204, val_target_losses:0.320970, best_flag:False
# 2021-04-09 11:02:48,022 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.09s/it]
# 2021-04-09 11:06:13,097 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:06:19,900 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:06:26,702 - pytorch_modeler.py - INFO - epoch:31/40, train_losses:8.45427050255239, val_source_losses:1.014522, val_target_losses:0.444962, best_flag:False
# 2021-04-09 11:06:26,703 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.08s/it]
# 2021-04-09 11:09:51,754 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:09:58,548 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:10:05,327 - pytorch_modeler.py - INFO - epoch:32/40, train_losses:6.289684124290943, val_source_losses:0.818312, val_target_losses:0.331036, best_flag:False
# 2021-04-09 11:10:05,328 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:13:29,958 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:13:36,754 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:13:43,532 - pytorch_modeler.py - INFO - epoch:33/40, train_losses:7.765311596449465, val_source_losses:0.899096, val_target_losses:0.408701, best_flag:False
# 2021-04-09 11:13:43,533 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:17:08,349 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:17:15,165 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:17:21,944 - pytorch_modeler.py - INFO - epoch:34/40, train_losses:6.65219712513499, val_source_losses:0.952485, val_target_losses:0.350116, best_flag:False
# 2021-04-09 11:17:21,945 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:20:46,773 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:20:53,556 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:21:00,363 - pytorch_modeler.py - INFO - epoch:35/40, train_losses:7.162218529498205, val_source_losses:0.848688, val_target_losses:0.376959, best_flag:False
# 2021-04-09 11:21:00,364 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:24:25,179 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:24:31,978 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:24:38,761 - pytorch_modeler.py - INFO - epoch:36/40, train_losses:6.496692619752139, val_source_losses:0.803031, val_target_losses:0.341931, best_flag:False
# 2021-04-09 11:24:38,762 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:28:03,512 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:28:10,318 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:28:17,116 - pytorch_modeler.py - INFO - epoch:37/40, train_losses:6.299658719217405, val_source_losses:0.831299, val_target_losses:0.331561, best_flag:False
# 2021-04-09 11:28:17,118 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:31:41,869 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:31:48,660 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:31:55,438 - pytorch_modeler.py - INFO - epoch:38/40, train_losses:7.145795677788556, val_source_losses:0.845927, val_target_losses:0.376095, best_flag:False
# 2021-04-09 11:31:55,440 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:35:20,216 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:35:27,002 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:35:33,785 - pytorch_modeler.py - INFO - epoch:39/40, train_losses:7.220094526186585, val_source_losses:0.809949, val_target_losses:0.380005, best_flag:False
# 2021-04-09 11:35:33,786 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:38:58,674 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:39:05,458 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 11:39:12,239 - pytorch_modeler.py - INFO - epoch:40/40, train_losses:7.332678318722174, val_source_losses:0.916264, val_target_losses:0.385930, best_flag:False
# 2021-04-09 11:39:12,242 - 00_train.py - INFO - TARGET MACHINE_TYPE: slider
# 2021-04-09 11:39:12,243 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-04-09 11:39:12,245 - 00_train.py - INFO - TRAINING
# elapsed time: 8939.840732813 [sec]
# 2021-04-09 11:39:14,501 - pytorch_modeler.py - INFO - train
#   0%|          | 0/189 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 189/189 [03:26<00:00,  1.09s/it]
# 2021-04-09 11:42:41,319 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.66it/s]
# 2021-04-09 11:42:51,347 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 11:42:51,348 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.45it/s]
# 2021-04-09 11:42:59,120 - pytorch_modeler.py - INFO - epoch:1/40, train_losses:37.77060979604721, val_source_losses:1.415523, val_target_losses:1.987927, best_flag:True
# 2021-04-09 11:42:59,121 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.09s/it]
# 2021-04-09 11:46:24,344 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 11:46:33,761 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 11:46:33,762 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:46:40,573 - pytorch_modeler.py - INFO - epoch:2/40, train_losses:36.523015320301056, val_source_losses:0.376485, val_target_losses:1.922264, best_flag:True
# 2021-04-09 11:46:40,575 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:50:05,467 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 11:50:12,397 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:50:19,206 - pytorch_modeler.py - INFO - epoch:3/40, train_losses:64.36590707302094, val_source_losses:0.575675, val_target_losses:3.387679, best_flag:False
# 2021-04-09 11:50:19,207 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:53:43,945 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.88it/s]
# 2021-04-09 11:53:50,894 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:53:57,698 - pytorch_modeler.py - INFO - epoch:4/40, train_losses:157.94418573379517, val_source_losses:3.458987, val_target_losses:8.312852, best_flag:False
# 2021-04-09 11:53:57,699 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 11:57:22,449 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 11:57:29,364 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 11:57:36,173 - pytorch_modeler.py - INFO - epoch:5/40, train_losses:117.28297810256481, val_source_losses:2.170137, val_target_losses:6.172788, best_flag:False
# 2021-04-09 11:57:36,174 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:01:00,954 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:01:07,878 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:01:14,697 - pytorch_modeler.py - INFO - epoch:6/40, train_losses:78.9409829378128, val_source_losses:1.382433, val_target_losses:4.154789, best_flag:False
# 2021-04-09 12:01:14,698 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:04:39,549 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:04:46,465 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:04:53,278 - pytorch_modeler.py - INFO - epoch:7/40, train_losses:110.93362951278687, val_source_losses:1.148175, val_target_losses:5.838612, best_flag:False
# 2021-04-09 12:04:53,278 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:08:18,145 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:08:25,063 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:08:31,886 - pytorch_modeler.py - INFO - epoch:8/40, train_losses:109.7094566822052, val_source_losses:1.058710, val_target_losses:5.774182, best_flag:False
# 2021-04-09 12:08:31,887 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:11:56,684 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:12:03,609 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:12:10,418 - pytorch_modeler.py - INFO - epoch:9/40, train_losses:70.31995034217834, val_source_losses:0.492805, val_target_losses:3.701050, best_flag:False
# 2021-04-09 12:12:10,419 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:15:35,140 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:15:42,071 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:15:48,876 - pytorch_modeler.py - INFO - epoch:10/40, train_losses:91.39256644248962, val_source_losses:0.760594, val_target_losses:4.810135, best_flag:False
# 2021-04-09 12:15:48,877 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:19:13,544 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:19:20,472 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
# 2021-04-09 12:19:27,300 - pytorch_modeler.py - INFO - epoch:11/40, train_losses:272.97848546504974, val_source_losses:5.972460, val_target_losses:14.367289, best_flag:False
# 2021-04-09 12:19:27,301 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:22:52,175 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:22:59,103 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:23:05,912 - pytorch_modeler.py - INFO - epoch:12/40, train_losses:78.53427416086197, val_source_losses:0.587645, val_target_losses:4.133383, best_flag:False
# 2021-04-09 12:23:05,913 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:26:30,703 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:26:37,620 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:26:44,423 - pytorch_modeler.py - INFO - epoch:13/40, train_losses:86.22952556610107, val_source_losses:0.545552, val_target_losses:4.538396, best_flag:False
# 2021-04-09 12:26:44,425 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.08s/it]
# 2021-04-09 12:30:09,435 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:30:16,360 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:30:23,164 - pytorch_modeler.py - INFO - epoch:14/40, train_losses:275.69072818756104, val_source_losses:4.205548, val_target_losses:14.510038, best_flag:False
# 2021-04-09 12:30:23,165 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:33:47,947 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:33:57,410 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 12:33:57,411 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.67it/s]
# 2021-04-09 12:34:04,530 - pytorch_modeler.py - INFO - epoch:15/40, train_losses:57.8052891343832, val_source_losses:0.340463, val_target_losses:3.042384, best_flag:True
# 2021-04-09 12:34:04,531 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:25<00:00,  1.08s/it]
# 2021-04-09 12:37:29,573 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:37:36,502 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
# 2021-04-09 12:37:43,329 - pytorch_modeler.py - INFO - epoch:16/40, train_losses:65.9573028087616, val_source_losses:0.556208, val_target_losses:3.471437, best_flag:False
# 2021-04-09 12:37:43,330 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:41:08,182 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:41:15,108 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.80it/s]
# 2021-04-09 12:41:21,908 - pytorch_modeler.py - INFO - epoch:17/40, train_losses:117.18955874443054, val_source_losses:1.435330, val_target_losses:6.167872, best_flag:False
# 2021-04-09 12:41:21,909 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:44:46,840 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:44:53,760 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:45:00,577 - pytorch_modeler.py - INFO - epoch:18/40, train_losses:125.45873031020164, val_source_losses:1.408120, val_target_losses:6.603091, best_flag:False
# 2021-04-09 12:45:00,578 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:48:25,440 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:48:32,355 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:48:39,164 - pytorch_modeler.py - INFO - epoch:19/40, train_losses:86.78545345924795, val_source_losses:0.883455, val_target_losses:4.567655, best_flag:False
# 2021-04-09 12:48:39,165 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:52:04,042 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:52:10,964 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:52:17,782 - pytorch_modeler.py - INFO - epoch:20/40, train_losses:46.00029046833515, val_source_losses:0.460537, val_target_losses:2.421068, best_flag:False
# 2021-04-09 12:52:17,783 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:55:42,589 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:55:49,508 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:55:56,311 - pytorch_modeler.py - INFO - epoch:21/40, train_losses:72.51387575268745, val_source_losses:0.530564, val_target_losses:3.816520, best_flag:False
# 2021-04-09 12:55:56,312 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 12:59:21,116 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 12:59:28,032 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 12:59:34,857 - pytorch_modeler.py - INFO - epoch:22/40, train_losses:67.62604959309101, val_source_losses:0.450377, val_target_losses:3.559266, best_flag:False
# 2021-04-09 12:59:34,858 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:02:59,800 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:03:09,255 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 13:03:09,256 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:03:16,079 - pytorch_modeler.py - INFO - epoch:23/40, train_losses:55.15887985378504, val_source_losses:0.307314, val_target_losses:2.903099, best_flag:True
# 2021-04-09 13:03:16,080 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:06:40,968 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:06:47,891 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
# 2021-04-09 13:06:54,730 - pytorch_modeler.py - INFO - epoch:24/40, train_losses:67.50648234784603, val_source_losses:0.507465, val_target_losses:3.552973, best_flag:False
# 2021-04-09 13:06:54,731 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:10:19,650 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:10:26,577 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:10:33,393 - pytorch_modeler.py - INFO - epoch:25/40, train_losses:96.53041553497314, val_source_losses:0.794955, val_target_losses:5.080548, best_flag:False
# 2021-04-09 13:10:33,395 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:13:58,253 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:14:05,174 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:14:11,986 - pytorch_modeler.py - INFO - epoch:26/40, train_losses:109.00071096420288, val_source_losses:0.863312, val_target_losses:5.736880, best_flag:False
# 2021-04-09 13:14:11,987 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:17:36,720 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:17:46,141 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 13:17:46,142 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.77it/s]
# 2021-04-09 13:17:53,000 - pytorch_modeler.py - INFO - epoch:27/40, train_losses:69.65182775259018, val_source_losses:0.251473, val_target_losses:3.665886, best_flag:True
# 2021-04-09 13:17:53,001 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:21:17,741 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:21:27,201 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 13:21:27,202 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:21:34,022 - pytorch_modeler.py - INFO - epoch:28/40, train_losses:53.935272082686424, val_source_losses:0.178748, val_target_losses:2.838699, best_flag:True
# 2021-04-09 13:21:34,023 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:24:58,825 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:25:05,743 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
# 2021-04-09 13:25:12,575 - pytorch_modeler.py - INFO - epoch:29/40, train_losses:57.162899762392044, val_source_losses:0.251663, val_target_losses:3.008574, best_flag:False
# 2021-04-09 13:25:12,576 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:28:37,352 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.88it/s]
# 2021-04-09 13:28:44,298 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:28:51,114 - pytorch_modeler.py - INFO - epoch:30/40, train_losses:54.70239470899105, val_source_losses:0.204867, val_target_losses:2.879073, best_flag:False
# 2021-04-09 13:28:51,115 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:32:16,019 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.88it/s]
# 2021-04-09 13:32:22,956 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:32:29,764 - pytorch_modeler.py - INFO - epoch:31/40, train_losses:61.178576707839966, val_source_losses:0.249936, val_target_losses:3.219925, best_flag:False
# 2021-04-09 13:32:29,765 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:35:54,646 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:36:01,579 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:36:08,393 - pytorch_modeler.py - INFO - epoch:32/40, train_losses:92.99223117530346, val_source_losses:0.512014, val_target_losses:4.894328, best_flag:False
# 2021-04-09 13:36:08,394 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:39:33,243 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:39:40,166 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:39:46,968 - pytorch_modeler.py - INFO - epoch:33/40, train_losses:61.37569776177406, val_source_losses:0.301736, val_target_losses:3.230300, best_flag:False
# 2021-04-09 13:39:46,969 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:43:11,852 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:43:18,778 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.79it/s]
# 2021-04-09 13:43:25,585 - pytorch_modeler.py - INFO - epoch:34/40, train_losses:66.30515405535698, val_source_losses:0.246750, val_target_losses:3.489745, best_flag:False
# 2021-04-09 13:43:25,586 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:24<00:00,  1.08s/it]
# 2021-04-09 13:46:50,570 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 2021-04-09 13:46:59,999 - pytorch_modeler.py - INFO - Save best model
# 2021-04-09 13:47:00,000 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.78it/s]
# 2021-04-09 13:47:06,830 - pytorch_modeler.py - INFO - epoch:35/40, train_losses:53.50504258275032, val_source_losses:0.174036, val_target_losses:2.816055, best_flag:True
# 2021-04-09 13:47:06,831 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:28<00:00,  1.10s/it]
# 2021-04-09 13:50:34,839 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.65it/s]
# 2021-04-09 13:50:42,386 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.66it/s]
# 2021-04-09 13:50:49,537 - pytorch_modeler.py - INFO - epoch:36/40, train_losses:66.7963433265686, val_source_losses:0.254577, val_target_losses:3.515597, best_flag:False
# 2021-04-09 13:50:49,538 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:36<00:00,  1.14s/it]
# 2021-04-09 13:54:25,754 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.78it/s]
# 2021-04-09 13:54:32,957 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:07<00:00,  2.70it/s]
# 2021-04-09 13:54:39,993 - pytorch_modeler.py - INFO - epoch:37/40, train_losses:63.715755105018616, val_source_losses:0.262787, val_target_losses:3.353461, best_flag:False
# 2021-04-09 13:54:39,994 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:31<00:00,  1.12s/it]
# 2021-04-09 13:58:11,481 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.83it/s]
# 2021-04-09 13:58:18,559 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.74it/s]
# 2021-04-09 13:58:25,508 - pytorch_modeler.py - INFO - epoch:38/40, train_losses:69.20112082362175, val_source_losses:0.341628, val_target_losses:3.642164, best_flag:False
# 2021-04-09 13:58:25,509 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:34<00:00,  1.13s/it]
# 2021-04-09 14:01:59,573 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.83it/s]
# 2021-04-09 14:02:06,642 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.74it/s]
# 2021-04-09 14:02:13,585 - pytorch_modeler.py - INFO - epoch:39/40, train_losses:68.30503508448601, val_source_losses:0.307082, val_target_losses:3.595002, best_flag:False
# 2021-04-09 14:02:13,587 - pytorch_modeler.py - INFO - train
# 100%|██████████| 189/189 [03:27<00:00,  1.10s/it]
# 2021-04-09 14:05:40,976 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 20/20 [00:07<00:00,  2.83it/s]
# 2021-04-09 14:05:48,058 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 19/19 [00:06<00:00,  2.73it/s]
# 2021-04-09 14:05:55,018 - pytorch_modeler.py - INFO - epoch:40/40, train_losses:74.70726355910301, val_source_losses:0.419819, val_target_losses:3.931961, best_flag:False
# 2021-04-09 14:05:55,021 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-04-09 14:05:55,022 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-04-09 14:05:55,050 - 00_train.py - INFO - TRAINING
# elapsed time: 8802.777592421 [sec]
# 2021-04-09 14:05:57,313 - pytorch_modeler.py - INFO - train
#   0%|          | 0/189 [00:00<?, ?it/s]
# use: cuda:0
#   1%|          | 1/189 [00:05<16:09,  5.16s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-952b15207ebd> in <module>
#       1 for machine_type in machine_types[2:]:
# ----> 2     run(machine_type, dev_paths)
#
# <ipython-input-9-0094d925fc1d> in run(machine_type, dev_paths)
#      34     net.load_state_dict(pretrained_dict['model'], strict=False)
#      35     # training
# ---> 36     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, criterion, scheduler, num_epochs, writer, model_out_path)
#      37
#      38     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/CNN_finetune/ex1/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, criterion, scheduler, num_epochs, writer, model_out_path)
#     131                     section_type = section_type.to(device)
#     132                     # model
# --> 133                     output_dict = net(input, section_type, mixup_lambda=None, layer_out=False)
#     134                     # calc loss
#     135                     loss = criterion(output_dict['pred_section_type'], section_type)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CNN_finetune/ex1/pytorch_model.py in forward(self, input, section_type, mixup_lambda, layer_out)
#     301             M_means.append(M_mean)
#     302
# --> 303         x, resM_means = self.resnet(x, layer_out=self.layer_out)
#     304         # CONCAT
#     305         if self.layer_out == True:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CNN_finetune/ex1/pytorch_model.py in forward(self, x, layer_out)
#     213             M_means.append(M_mean)
#     214
# --> 215         x = self.layer3(x)
#     216         # APPEND M_mean
#     217         if layer_out == True:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CNN_finetune/ex1/pytorch_model.py in forward(self, x)
#     122         out = F.dropout(out, p=0.1, training=self.training)
#     123
# --> 124         out = self.conv2(out)
#     125         out = self.bn2(out)
#     126
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     421
#     422     def forward(self, input: Tensor) -> Tensor:
# --> 423         return self._conv_forward(input, self.weight)
#     424
#     425 class Conv3d(_ConvNd):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight)
#     417                             weight, self.bias, self.stride,
#     418                             _pair(0), self.dilation, self.groups)
# --> 419         return F.conv2d(input, weight, self.bias, self.stride,
#     420                         self.padding, self.dilation, self.groups)
#     421
#
# RuntimeError: CUDA out of memory. Tried to allocate 32.00 MiB (GPU 0; 11.77 GiB total capacity; 10.12 GiB already allocated; 79.25 MiB free; 10.22 GiB reserved in total by PyTorch)

# %%
machine_type = 'pump'
input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
ext_data = pd.read_pickle(input_path)

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['valid_source']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %% [markdown]
# history = run('ToyCar')
# with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#     pickle.dump(history , file)

# %%
print(M_means.shape)
plt.imshow(M_means, aspect='auto', cmap='jet')
plt.title(phase)
plt.colorbar()
plt.show()

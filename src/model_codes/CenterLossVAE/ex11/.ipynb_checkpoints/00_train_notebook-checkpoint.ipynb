# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/ex10/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
pd.DataFrame(ext_data['train']['features'])
# Out:
#           0         1         2         3         4         5         6     \
# 0     0.243716  0.338328  0.272088  0.226127  0.029367  0.339973  0.209255
# 1     0.237665  0.327515  0.263212  0.232293  0.027842  0.367579  0.210006
# 2     0.225514  0.379070  0.276066  0.196089  0.027455  0.265828  0.224954
# 3     0.241087  0.328841  0.287649  0.230211  0.029166  0.339409  0.215851
# 4     0.247998  0.328309  0.278905  0.237095  0.027144  0.362545  0.209568
# ...        ...       ...       ...       ...       ...       ...       ...
# 6013  0.242294  0.320149  0.291148  0.246376  0.024519  0.336719  0.213888
# 6014  0.239820  0.328761  0.283221  0.232255  0.026091  0.329097  0.217799
# 6015  0.233884  0.312639  0.287863  0.243157  0.024677  0.309460  0.243808
# 6016  0.232720  0.344319  0.275893  0.233720  0.027888  0.292808  0.227276
# 6017  0.240835  0.323781  0.284896  0.247816  0.026225  0.330116  0.219588
#
#           7         8         9     ...      3766      3767      3768  \
# 0     0.105823  0.137297  0.145012  ...  0.022174  0.006773  0.069666
# 1     0.094775  0.134482  0.143913  ...  0.027657  0.028354  0.165744
# 2     0.132161  0.143215  0.143278  ...  0.040949  0.034133  0.122343
# 3     0.104063  0.135149  0.140004  ...  0.047530  0.000834  0.029579
# 4     0.100579  0.133083  0.137760  ...  0.022089  0.001686  0.082939
# ...        ...       ...       ...  ...       ...       ...       ...
# 6013  0.098774  0.152700  0.135828  ...  0.028749  0.020032  0.089271
# 6014  0.107723  0.151887  0.142054  ...  0.065597  0.009168  0.159468
# 6015  0.103488  0.180332  0.135159  ...  0.159631  0.007203  0.071548
# 6016  0.124664  0.170116  0.145821  ...  0.098789  0.002348  0.054095
# 6017  0.103428  0.161958  0.136787  ...  0.093452  0.001229  0.112384
#
#           3769      3770      3771      3772      3773      3774      3775
# 0     0.301964  0.180498  0.033291  0.098398  0.024299  0.016897  0.123153
# 1     0.330388  0.136494  0.035396  0.146613  0.123391  0.007483  0.144597
# 2     0.213779  0.166338  0.049096  0.042672  0.044685  0.002102  0.145841
# 3     0.157189  0.159237  0.092072  0.176285  0.072260  0.025339  0.222447
# 4     0.303310  0.165293  0.078591  0.169059  0.093608  0.015137  0.118250
# ...        ...       ...       ...       ...       ...       ...       ...
# 6013  0.324535  0.164114  0.011856  0.131130  0.048871  0.016199  0.125525
# 6014  0.321171  0.235521  0.020378  0.059581  0.037248  0.034675  0.046954
# 6015  0.284185  0.112961  0.240836  0.032650  0.014332  0.023457  0.157205
# 6016  0.253814  0.089476  0.159530  0.034791  0.019259  0.031108  0.169736
# 6017  0.231182  0.136114  0.127123  0.077272  0.065049  0.030027  0.154239
#
# [6018 rows x 3776 columns]

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
for machine_type in machine_types:
    run(machine_type)
# Out:
# 2021-05-26 22:43:10,739 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-05-26 22:43:10,740 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-26 22:43:10,792 - 00_train.py - INFO - TRAINING
# 2021-05-26 22:43:15,914 - pytorch_modeler.py - INFO - train
#   0%|          | 0/12 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 12/12 [00:01<00:00,  7.30it/s]
# 2021-05-26 22:43:17,562 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 70.22it/s]
# 2021-05-26 22:43:17,638 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 70.45it/s]
#                AUC      pAUC
# Source_0  0.593100  0.534737
# Source_1  0.619300  0.530526
# Source_2  0.679600  0.582105
# Target_0  0.636900  0.580000
# Target_1  0.772300  0.589474
# Target_2  0.774550  0.697895
# mean      0.679292  0.585789
# h_mean    0.672024  0.581038
# 2021-05-26 22:43:18,749 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:58691.984701, val_AUC_hmean:0.672024, val_pAUC_hmean:0.581038, best_flag:True
# 2021-05-26 22:43:18,750 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 12.81it/s]
# 2021-05-26 22:43:19,689 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 33.61it/s]
# 2021-05-26 22:43:19,773 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 31.49it/s]
# 2021-05-26 22:43:19,866 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:42713.963216, val_AUC_hmean:0.663431, val_pAUC_hmean:0.551390, best_flag:False
# 2021-05-26 22:43:19,867 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 13.91it/s]
# 2021-05-26 22:43:20,733 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 51.32it/s]
# 2021-05-26 22:43:20,798 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 77.04it/s]
# 2021-05-26 22:43:20,849 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:36896.346680, val_AUC_hmean:0.623765, val_pAUC_hmean:0.530220, best_flag:False
# 2021-05-26 22:43:20,851 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.98it/s]
# 2021-05-26 22:43:21,605 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.50it/s]
# 2021-05-26 22:43:21,668 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 58.37it/s]
# 2021-05-26 22:43:21,726 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:34155.538086, val_AUC_hmean:0.614301, val_pAUC_hmean:0.511704, best_flag:False
# 2021-05-26 22:43:21,728 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.54it/s]
# 2021-05-26 22:43:22,456 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 39.28it/s]
# 2021-05-26 22:43:22,531 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 36.63it/s]
# 2021-05-26 22:43:22,611 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:32612.024740, val_AUC_hmean:0.540130, val_pAUC_hmean:0.504557, best_flag:False
# 2021-05-26 22:43:22,612 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:01<00:00, 11.71it/s]
# 2021-05-26 22:43:23,641 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 47.63it/s]
# 2021-05-26 22:43:23,714 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 58.39it/s]
# 2021-05-26 22:43:23,770 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:31683.552734, val_AUC_hmean:0.580863, val_pAUC_hmean:0.511386, best_flag:False
# 2021-05-26 22:43:23,771 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.93it/s]
# 2021-05-26 22:43:24,482 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 52.26it/s]
# 2021-05-26 22:43:24,542 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 63.95it/s]
# 2021-05-26 22:43:24,604 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:31257.505697, val_AUC_hmean:0.583476, val_pAUC_hmean:0.503202, best_flag:False
# 2021-05-26 22:43:24,605 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 17.12it/s]
# 2021-05-26 22:43:25,307 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.65it/s]
# 2021-05-26 22:43:25,369 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 61.63it/s]
# 2021-05-26 22:43:25,428 - pytorch_modeler.py - INFO - epoch:8/300, train_losses:30688.897624, val_AUC_hmean:0.510223, val_pAUC_hmean:0.507453, best_flag:False
# 2021-05-26 22:43:25,430 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:01<00:00, 11.37it/s]
# 2021-05-26 22:43:26,487 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 40.71it/s]
# 2021-05-26 22:43:26,559 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 49.13it/s]
# 2021-05-26 22:43:26,625 - pytorch_modeler.py - INFO - epoch:9/300, train_losses:30285.571615, val_AUC_hmean:0.548400, val_pAUC_hmean:0.507558, best_flag:False
# 2021-05-26 22:43:26,626 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.27it/s]
# 2021-05-26 22:43:27,417 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 35.52it/s]
# 2021-05-26 22:43:27,499 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 36.81it/s]
# 2021-05-26 22:43:27,577 - pytorch_modeler.py - INFO - epoch:10/300, train_losses:29904.197103, val_AUC_hmean:0.576126, val_pAUC_hmean:0.508081, best_flag:False
# 2021-05-26 22:43:27,578 - pytorch_modeler.py - INFO - train
#  17%|█▋        | 2/12 [00:00<00:01,  9.34it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-9c47a29ad1dc> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type)
#
# <ipython-input-10-540674391f48> in run(machine_type)
#      30     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      31     # training
# ---> 32     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      33
#      34     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/ex10/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     128                     target_bool = target_bool.to(device)
#     129                     # model
# --> 130                     output_dict = net(input, section_type, target_bool, device)
#     131                     # calc loss
#     132                     loss, x_hat = output_dict['reconst_error'], output_dict['reconstruction']
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/ex10/pytorch_model.py in forward(self, input, section_type, target_bool, device)
#     166         #x = self.bn0(input)
#     167         x_gt = x.clone()
# --> 168         x = self.Encoder(x)
#     169         x = self.fc_block1(x, use_tanh=False)
#     170         # for center_loss
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/ex10/pytorch_model.py in forward(self, input)
#      94     def forward(self, input):
#      95         x = input
# ---> 96         x = self.fc_block1(x)
#      97         x = self.fc_block2(x)
#      98         x = self.fc_block3(x)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/ex10/pytorch_model.py in forward(self, input, use_tanh)
#      80             x = torch.tanh_(self.bn1(self.fc1(x)))
#      81         else:
# ---> 82             x = F.relu_(self.bn1(self.fc1(x)))
#      83         return x
#      84
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     133         assert self.running_mean is None or isinstance(self.running_mean, torch.Tensor)
#     134         assert self.running_var is None or isinstance(self.running_var, torch.Tensor)
# --> 135         return F.batch_norm(
#     136             input,
#     137             # If buffers are not to be tracked, ensure that they won't be updated
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2147         _verify_batch_size(input.size())
#    2148
# -> 2149     return torch.batch_norm(
#    2150         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2151     )
#
# KeyboardInterrupt:

# %%
#run(machine_types[0])

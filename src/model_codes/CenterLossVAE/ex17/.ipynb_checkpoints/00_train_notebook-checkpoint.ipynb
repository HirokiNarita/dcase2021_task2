# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle
import random
from random import sample

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/ex17/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#ext_data = pd.read_pickle(f'{INPUT_ROOT}/valve_features.pkl')

# %%
#sns.distplot(ext_data['train']['features'][:,0])

# %%
#train_features = ext_data['train']['features']

# %%
#train_features.shape

# %% [markdown]
# ## training

# %%
def random_feature_selection(x, t_d=3776, d=2048):
    idx = torch.tensor(sample(range(0, t_d), d)) # t_d(特徴量)の中からランダムにd個サンプリングする(ぜんぶやると重いから) # わからん
    # 0~t_d idxの中からランダムにd個サンプリングする
    x = np.take(x, idx, 1)
    return x

# %%
#ext_data['train'].keys()

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dataloader
    #for machine in machine_types:
    #    if machine_type == machine:
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_features.pkl')
    
    #    else:
    #        ext_data_ = pd.read_pickle(f'{INPUT_ROOT}/{machine}_features.pkl')
    #        ext_data['train']['features'] = np.concatenate([ext_data['train']['features'],
    #                                                        ext_data_['train']['features']], axis=0)
    #        ext_data['train']['labels'] = np.concatenate([ext_data['train']['labels'],
    #                                                     ext_data_['train']['labels']], axis=0)
    #        ext_data['train']['wav_names'] = np.concatenate([ext_data['train']['wav_names'],
    #                                                         ext_data_['train']['wav_names']], axis=0)
            
    #t_d = 3776    # 全特徴量数
    #d = 1024      # 使う特徴量数
    #for phase in ['train', 'valid_source', 'valid_target']:
    #    x = ext_data[phase]['features']
    #    x = random_feature_selection(x)
    #    ext_data[phase]['features'] = x
    #    x = ext_data[phase]['features'][:,512:2048]
    #    ext_data[phase]['features'] = x
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['train']['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-4)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
#for machine_type in machine_types:
#    run(machine_type)
# Out:
# 2021-05-30 22:39:46,454 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-05-30 22:39:46,455 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-30 22:39:47,418 - 00_train.py - INFO - TRAINING
# 2021-05-30 22:39:52,176 - pytorch_modeler.py - INFO - train
#   0%|          | 0/12 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 12/12 [00:01<00:00,  9.91it/s]
# 2021-05-30 22:39:53,390 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 51.47it/s]
# 2021-05-30 22:39:53,460 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 69.75it/s]
#                AUC      pAUC
# Source_0  0.463000  0.487368
# Source_1  0.511200  0.486316
# Source_2  0.587400  0.521053
# Target_0  0.403100  0.494211
# Target_1  0.442400  0.493158
# Target_2  0.441400  0.485263
# mean      0.474750  0.494561
# h_mean    0.467832  0.494266
# 2021-05-30 22:39:55,283 - pytorch_modeler.py - INFO - epoch:1/300, train_losses:848.179738, val_AUC_hmean:0.467832, val_pAUC_hmean:0.494266, best_flag:True
# 2021-05-30 22:39:55,285 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.93it/s]
# 2021-05-30 22:39:55,996 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 63.76it/s]
# 2021-05-30 22:39:56,048 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 65.20it/s]
#                AUC      pAUC
# Source_0  0.753600  0.627895
# Source_1  0.645900  0.516316
# Source_2  0.743700  0.592632
# Target_0  0.675000  0.641053
# Target_1  0.828600  0.670526
# Target_2  0.591000  0.517368
# mean      0.706300  0.594298
# h_mean    0.697658  0.588179
# 2021-05-30 22:39:57,786 - pytorch_modeler.py - INFO - epoch:2/300, train_losses:556.746503, val_AUC_hmean:0.697658, val_pAUC_hmean:0.588179, best_flag:True
# 2021-05-30 22:39:57,786 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.32it/s]
# 2021-05-30 22:39:58,524 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.78it/s]
# 2021-05-30 22:39:58,585 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 58.44it/s]
# 2021-05-30 22:39:58,644 - pytorch_modeler.py - INFO - epoch:3/300, train_losses:444.752027, val_AUC_hmean:0.660002, val_pAUC_hmean:0.563520, best_flag:False
# 2021-05-30 22:39:58,646 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.27it/s]
# 2021-05-30 22:39:59,385 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.86it/s]
# 2021-05-30 22:39:59,447 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 55.78it/s]
# 2021-05-30 22:39:59,507 - pytorch_modeler.py - INFO - epoch:4/300, train_losses:389.107206, val_AUC_hmean:0.619171, val_pAUC_hmean:0.528267, best_flag:False
# 2021-05-30 22:39:59,508 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 19.98it/s]
# 2021-05-30 22:40:00,111 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 78.73it/s]
# 2021-05-30 22:40:00,157 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 87.51it/s]
# 2021-05-30 22:40:00,205 - pytorch_modeler.py - INFO - epoch:5/300, train_losses:359.142484, val_AUC_hmean:0.588637, val_pAUC_hmean:0.553779, best_flag:False
# 2021-05-30 22:40:00,207 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 19.03it/s]
# 2021-05-30 22:40:00,840 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 64.20it/s]
# 2021-05-30 22:40:00,906 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 62.92it/s]
# 2021-05-30 22:40:00,969 - pytorch_modeler.py - INFO - epoch:6/300, train_losses:343.448407, val_AUC_hmean:0.668070, val_pAUC_hmean:0.576238, best_flag:False
# 2021-05-30 22:40:00,970 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 22.99it/s]
# 2021-05-30 22:40:01,494 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 86.74it/s]
# 2021-05-30 22:40:01,540 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 72.57it/s]
# 2021-05-30 22:40:01,598 - pytorch_modeler.py - INFO - epoch:7/300, train_losses:329.379166, val_AUC_hmean:0.684353, val_pAUC_hmean:0.577160, best_flag:False
# 2021-05-30 22:40:01,600 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.93it/s]
# 2021-05-30 22:40:02,355 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 59.09it/s]
# 2021-05-30 22:40:02,421 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 67.05it/s]
# 2021-05-30 22:40:02,481 - pytorch_modeler.py - INFO - epoch:8/300, train_losses:320.820279, val_AUC_hmean:0.691398, val_pAUC_hmean:0.573880, best_flag:False
# 2021-05-30 22:40:02,482 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.32it/s]
# 2021-05-30 22:40:03,268 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 60.35it/s]
# 2021-05-30 22:40:03,328 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 92.22it/s]
# 2021-05-30 22:40:03,387 - pytorch_modeler.py - INFO - epoch:9/300, train_losses:313.265806, val_AUC_hmean:0.689285, val_pAUC_hmean:0.568464, best_flag:False
# 2021-05-30 22:40:03,388 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 17.63it/s]
# 2021-05-30 22:40:04,071 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 53.11it/s]
# 2021-05-30 22:40:04,131 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 66.68it/s]
# 2021-05-30 22:40:04,188 - pytorch_modeler.py - INFO - epoch:10/300, train_losses:308.931099, val_AUC_hmean:0.690798, val_pAUC_hmean:0.574727, best_flag:False
# 2021-05-30 22:40:04,189 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.57it/s]
# 2021-05-30 22:40:04,915 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.40it/s]
# 2021-05-30 22:40:04,980 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 63.35it/s]
# 2021-05-30 22:40:05,038 - pytorch_modeler.py - INFO - epoch:11/300, train_losses:304.409401, val_AUC_hmean:0.680589, val_pAUC_hmean:0.584543, best_flag:False
# 2021-05-30 22:40:05,039 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.49it/s]
# 2021-05-30 22:40:05,769 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 52.40it/s]
# 2021-05-30 22:40:05,834 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 58.92it/s]
# 2021-05-30 22:40:05,895 - pytorch_modeler.py - INFO - epoch:12/300, train_losses:298.107903, val_AUC_hmean:0.617164, val_pAUC_hmean:0.569741, best_flag:False
# 2021-05-30 22:40:05,896 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.54it/s]
# 2021-05-30 22:40:06,624 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 51.11it/s]
# 2021-05-30 22:40:06,687 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 75.11it/s]
# 2021-05-30 22:40:06,738 - pytorch_modeler.py - INFO - epoch:13/300, train_losses:293.660540, val_AUC_hmean:0.678719, val_pAUC_hmean:0.562268, best_flag:False
# 2021-05-30 22:40:06,739 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.31it/s]
# 2021-05-30 22:40:07,477 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 55.94it/s]
# 2021-05-30 22:40:07,547 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 46.32it/s]
# 2021-05-30 22:40:07,626 - pytorch_modeler.py - INFO - epoch:14/300, train_losses:290.047468, val_AUC_hmean:0.649608, val_pAUC_hmean:0.569810, best_flag:False
# 2021-05-30 22:40:07,627 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.43it/s]
# 2021-05-30 22:40:08,360 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 60.22it/s]
# 2021-05-30 22:40:08,419 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 75.97it/s]
# 2021-05-30 22:40:08,481 - pytorch_modeler.py - INFO - epoch:15/300, train_losses:285.786641, val_AUC_hmean:0.633773, val_pAUC_hmean:0.567792, best_flag:False
# 2021-05-30 22:40:08,482 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.03it/s]
# 2021-05-30 22:40:09,233 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 49.72it/s]
# 2021-05-30 22:40:09,300 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 53.32it/s]
# 2021-05-30 22:40:09,361 - pytorch_modeler.py - INFO - epoch:16/300, train_losses:282.319293, val_AUC_hmean:0.628408, val_pAUC_hmean:0.576755, best_flag:False
# 2021-05-30 22:40:09,362 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.65it/s]
# 2021-05-30 22:40:10,085 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 55.88it/s]
# 2021-05-30 22:40:10,149 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 60.94it/s]
# 2021-05-30 22:40:10,212 - pytorch_modeler.py - INFO - epoch:17/300, train_losses:280.198176, val_AUC_hmean:0.587198, val_pAUC_hmean:0.536574, best_flag:False
# 2021-05-30 22:40:10,213 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.75it/s]
# 2021-05-30 22:40:10,931 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 48.92it/s]
# 2021-05-30 22:40:10,998 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 55.94it/s]
# 2021-05-30 22:40:11,058 - pytorch_modeler.py - INFO - epoch:18/300, train_losses:279.213473, val_AUC_hmean:0.649262, val_pAUC_hmean:0.538794, best_flag:False
# 2021-05-30 22:40:11,059 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.74it/s]
# 2021-05-30 22:40:11,778 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 48.05it/s]
# 2021-05-30 22:40:11,845 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 59.97it/s]
# 2021-05-30 22:40:11,904 - pytorch_modeler.py - INFO - epoch:19/300, train_losses:275.266864, val_AUC_hmean:0.602271, val_pAUC_hmean:0.557156, best_flag:False
# 2021-05-30 22:40:11,905 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.40it/s]
# 2021-05-30 22:40:12,639 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 48.88it/s]
# 2021-05-30 22:40:12,712 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 63.28it/s]
# 2021-05-30 22:40:12,775 - pytorch_modeler.py - INFO - epoch:20/300, train_losses:270.270017, val_AUC_hmean:0.623240, val_pAUC_hmean:0.543320, best_flag:False
# 2021-05-30 22:40:12,776 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.46it/s]
# 2021-05-30 22:40:13,507 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 59.94it/s]
# 2021-05-30 22:40:13,563 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 63.89it/s]
# 2021-05-30 22:40:13,620 - pytorch_modeler.py - INFO - epoch:21/300, train_losses:266.360761, val_AUC_hmean:0.629532, val_pAUC_hmean:0.562342, best_flag:False
# 2021-05-30 22:40:13,621 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.52it/s]
# 2021-05-30 22:40:14,350 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 55.21it/s]
# 2021-05-30 22:40:14,414 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 67.00it/s]
# 2021-05-30 22:40:14,475 - pytorch_modeler.py - INFO - epoch:22/300, train_losses:263.457479, val_AUC_hmean:0.589114, val_pAUC_hmean:0.545276, best_flag:False
# 2021-05-30 22:40:14,477 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.65it/s]
# 2021-05-30 22:40:15,199 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 60.25it/s]
# 2021-05-30 22:40:15,253 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 76.06it/s]
# 2021-05-30 22:40:15,308 - pytorch_modeler.py - INFO - epoch:23/300, train_losses:261.886233, val_AUC_hmean:0.644968, val_pAUC_hmean:0.545464, best_flag:False
# 2021-05-30 22:40:15,309 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.59it/s]
# 2021-05-30 22:40:16,035 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 52.90it/s]
# 2021-05-30 22:40:16,099 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 67.40it/s]
# 2021-05-30 22:40:16,156 - pytorch_modeler.py - INFO - epoch:24/300, train_losses:260.942607, val_AUC_hmean:0.633164, val_pAUC_hmean:0.537141, best_flag:False
# 2021-05-30 22:40:16,157 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.35it/s]
# 2021-05-30 22:40:16,894 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 68.85it/s]
# 2021-05-30 22:40:16,943 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 56.87it/s]
# 2021-05-30 22:40:17,011 - pytorch_modeler.py - INFO - epoch:25/300, train_losses:258.319750, val_AUC_hmean:0.604597, val_pAUC_hmean:0.550015, best_flag:False
# 2021-05-30 22:40:17,012 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.28it/s]
# 2021-05-30 22:40:17,799 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 60.19it/s]
# 2021-05-30 22:40:17,855 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 72.70it/s]
# 2021-05-30 22:40:17,917 - pytorch_modeler.py - INFO - epoch:26/300, train_losses:256.740245, val_AUC_hmean:0.562250, val_pAUC_hmean:0.543065, best_flag:False
# 2021-05-30 22:40:17,919 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.67it/s]
# 2021-05-30 22:40:18,641 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 67.77it/s]
# 2021-05-30 22:40:18,694 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 57.74it/s]
# 2021-05-30 22:40:18,758 - pytorch_modeler.py - INFO - epoch:27/300, train_losses:254.140850, val_AUC_hmean:0.582777, val_pAUC_hmean:0.541377, best_flag:False
# 2021-05-30 22:40:18,759 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.80it/s]
# 2021-05-30 22:40:19,521 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 50.97it/s]
# 2021-05-30 22:40:19,585 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 71.46it/s]
# 2021-05-30 22:40:19,652 - pytorch_modeler.py - INFO - epoch:28/300, train_losses:249.256273, val_AUC_hmean:0.590836, val_pAUC_hmean:0.544061, best_flag:False
# 2021-05-30 22:40:19,654 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.22it/s]
# 2021-05-30 22:40:20,395 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 54.43it/s]
# 2021-05-30 22:40:20,454 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 74.90it/s]
# 2021-05-30 22:40:20,516 - pytorch_modeler.py - INFO - epoch:29/300, train_losses:246.312127, val_AUC_hmean:0.631831, val_pAUC_hmean:0.562031, best_flag:False
# 2021-05-30 22:40:20,517 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.23it/s]
# 2021-05-30 22:40:21,258 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 62.42it/s]
# 2021-05-30 22:40:21,312 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 77.51it/s]
# 2021-05-30 22:40:21,366 - pytorch_modeler.py - INFO - epoch:30/300, train_losses:243.541800, val_AUC_hmean:0.612299, val_pAUC_hmean:0.539874, best_flag:False
# 2021-05-30 22:40:21,367 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.49it/s]
# 2021-05-30 22:40:22,097 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 49.72it/s]
# 2021-05-30 22:40:22,162 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 66.97it/s]
# 2021-05-30 22:40:22,232 - pytorch_modeler.py - INFO - epoch:31/300, train_losses:244.087646, val_AUC_hmean:0.596303, val_pAUC_hmean:0.548248, best_flag:False
# 2021-05-30 22:40:22,233 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.33it/s]
# 2021-05-30 22:40:22,970 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 51.83it/s]
# 2021-05-30 22:40:23,036 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 66.97it/s]
# 2021-05-30 22:40:23,097 - pytorch_modeler.py - INFO - epoch:32/300, train_losses:241.338109, val_AUC_hmean:0.630869, val_pAUC_hmean:0.542707, best_flag:False
# 2021-05-30 22:40:23,098 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 15.22it/s]
# 2021-05-30 22:40:23,889 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 44.67it/s]
# 2021-05-30 22:40:23,969 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 76.82it/s]
# 2021-05-30 22:40:24,032 - pytorch_modeler.py - INFO - epoch:33/300, train_losses:238.992808, val_AUC_hmean:0.625198, val_pAUC_hmean:0.557982, best_flag:False
# 2021-05-30 22:40:24,033 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 20.87it/s]
# 2021-05-30 22:40:24,610 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 79.61it/s]
# 2021-05-30 22:40:24,659 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 80.41it/s]
# 2021-05-30 22:40:24,708 - pytorch_modeler.py - INFO - epoch:34/300, train_losses:236.886528, val_AUC_hmean:0.583281, val_pAUC_hmean:0.539218, best_flag:False
# 2021-05-30 22:40:24,710 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 24.36it/s]
# 2021-05-30 22:40:25,205 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 77.11it/s]
# 2021-05-30 22:40:25,251 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 74.67it/s]
# 2021-05-30 22:40:25,310 - pytorch_modeler.py - INFO - epoch:35/300, train_losses:234.439027, val_AUC_hmean:0.562683, val_pAUC_hmean:0.539219, best_flag:False
# 2021-05-30 22:40:25,311 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 23.95it/s]
# 2021-05-30 22:40:25,814 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 85.37it/s]
# 2021-05-30 22:40:25,872 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 67.47it/s]
# 2021-05-30 22:40:25,931 - pytorch_modeler.py - INFO - epoch:36/300, train_losses:232.830424, val_AUC_hmean:0.628756, val_pAUC_hmean:0.549248, best_flag:False
# 2021-05-30 22:40:25,932 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.41it/s]
# 2021-05-30 22:40:26,667 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 46.75it/s]
# 2021-05-30 22:40:26,736 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 57.52it/s]
# 2021-05-30 22:40:26,796 - pytorch_modeler.py - INFO - epoch:37/300, train_losses:230.253352, val_AUC_hmean:0.630194, val_pAUC_hmean:0.549040, best_flag:False
# 2021-05-30 22:40:26,797 - pytorch_modeler.py - INFO - train
# 100%|██████████| 12/12 [00:00<00:00, 16.87it/s]
# 2021-05-30 22:40:27,511 - pytorch_modeler.py - INFO - valid_source
# 100%|██████████| 2/2 [00:00<00:00, 40.11it/s]
# 2021-05-30 22:40:27,593 - pytorch_modeler.py - INFO - valid_target
# 100%|██████████| 2/2 [00:00<00:00, 68.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-9c47a29ad1dc> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type)
#
# <ipython-input-14-1e76046c4e28> in run(machine_type)
#      49     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      50     # training
# ---> 51     output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#      52
#      53     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/ex17/pytorch_modeler.py in train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
#     227                 section_types = torch.cat(section_types).detach().numpy().copy()
#     228                 # calc score
# --> 229                 all_scores_df = com.calc_DCASE2021_score(all_scores_df, labels, preds, section_types, phase, wav_names)
#     230                 # preds
#     231                 describe_df_ = com.get_pred_discribe(labels, preds, section_types, wav_names)
#
# ~/research/dcase2021_task2/src/functions/common.py in calc_DCASE2021_score(all_scores_df, labels, preds, section_types, phase, wav_names)
#     503 def calc_DCASE2021_score(all_scores_df, labels, preds, section_types, phase, wav_names):
#     504     describe_df = get_pred_discribe(labels, preds, section_types, wav_names)
# --> 505     scores_df = get_score_per_Section(describe_df, max_fpr=0.1)
#     506     # 結合(source + target)
#     507     if phase == 'valid_source':
#
# ~/research/dcase2021_task2/src/functions/common.py in get_score_per_Section(describe_df, max_fpr)
#     488         per_section_df = describe_df[describe_df['section_types'] == section]
#     489         per_section_AUC = roc_auc_score(per_section_df['labels'], per_section_df['preds'])
# --> 490         per_section_pAUC = roc_auc_score(per_section_df['labels'], per_section_df['preds'], max_fpr=max_fpr)
#     491         # column = [AUC,pAUC], row = index
#     492         score_df = pd.DataFrame(np.stack([per_section_AUC, per_section_pAUC]), index=['AUC', 'pAUC']).T
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     540         labels = np.unique(y_true)
#     541         y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 542         return _average_binary_score(partial(_binary_roc_auc_score,
#     543                                              max_fpr=max_fpr),
#     544                                      y_true, y_score, average,
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     328                          "is not defined in that case.")
#     329
# --> 330     fpr, tpr, _ = roc_curve(y_true, y_score,
#     331                             sample_weight=sample_weight)
#     332     if max_fpr is None or max_fpr == 1:
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     935     # to make sure that the curve starts at (0, 0)
#     936     tps = np.r_[0, tps]
# --> 937     fps = np.r_[0, fps]
#     938     thresholds = np.r_[thresholds[0] + 1, thresholds]
#     939
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/numpy/lib/index_tricks.py in __getitem__(self, key)
#     399
#     400         # Ensure that scalars won't up-cast unless warranted
# --> 401         final_dtype = find_common_type(arraytypes, scalartypes)
#     402         if final_dtype is not None:
#     403             for k in scalars:
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/numpy/core/numerictypes.py in find_common_type(array_types, scalar_types)
#     620     """
#     621     array_types = [dtype(x) for x in array_types]
# --> 622     scalar_types = [dtype(x) for x in scalar_types]
#     623
#     624     maxa = _can_coerce_all(array_types)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/numpy/core/numerictypes.py in <listcomp>(.0)
#     620     """
#     621     array_types = [dtype(x) for x in array_types]
# --> 622     scalar_types = [dtype(x) for x in scalar_types]
#     623
#     624     maxa = _can_coerce_all(array_types)
#
# KeyboardInterrupt:

# %%
run(machine_types[2])

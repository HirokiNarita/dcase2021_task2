# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle
import random
from random import sample

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import Conditional_VAE as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/train_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(777)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
#dev_dir = INPUT_ROOT + "/dev_data"
#add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
OUT_SCORE_DIR = OUTPUT_ROOT + '/score'
OUT_PRED_DIR = OUTPUT_ROOT + '/pred'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
os.makedirs(OUT_SCORE_DIR, exist_ok=True)
os.makedirs(OUT_PRED_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/CenterLossVAE/ex15_subseq/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
#ext_data = pd.read_pickle(f'{INPUT_ROOT}/ToyCar_valid_source_features.pkl')

# %%
#ext_data['features'][-1].shape

# %%
# 938(subseq length) * 600(n_samples)
# wav_name = []
# for i in range(len(ext_data['wav_name'])):
#     per_wav_name = [ext_data['wav_name'][i]]
#     per_n_samples = ext_data['features'][0].shape[0]
#     wav_name.extend(per_wav_name * per_n_samples)

# %% [markdown]
# ## training

# %%
def random_feature_selection(x, t_d=3776, d=2048):
    idx = torch.tensor(sample(range(0, t_d), d)) # t_d(特徴量)の中からランダムにd個サンプリングする(ぜんぶやると重いから) # わからん
    # 0~t_d idxの中からランダムにd個サンプリングする
    x = np.take(x, idx, 1)
    return x

# %%
# ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_train_features.pkl')
# # 938(subseq length) * 600(n_samples)
# wav_name = []
# for i in range(len(ext_data['wav_name'])):
#     per_wav_name = [ext_data['wav_name'][i]]
#     per_n_samples = ext_data['features'][0].shape[0]
#     wav_name.extend(per_wav_name * per_n_samples)
# ext_data['wav_name'] = wav_name
# ext_data['features'] = np.concatenate(ext_data['features'], axis=0)

# %%
#ext_data['label']

# %%
#len(ext_data['wav_name'])

# %%
#ext_data['features'].shape

# %%
#ext_data['train'].keys()

# %%
#############################################################################
# run
#############################################################################
def run(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_train_features.pkl')
    # 938(subseq length) * 600(n_samples)
    wav_name = []
    for i in range(len(ext_data['wav_name'])):
        per_wav_name = [ext_data['wav_name'][i]]
        per_n_samples = ext_data['features'][0].shape[0]
        wav_name.extend(per_wav_name * per_n_samples)
    ext_data['wav_name'] = wav_name
    ext_data['features'] = np.concatenate(ext_data['features'], axis=0)
    
    # dataloader
    #for machine in machine_types:
    #    if machine_type == machine:
    #        ext_data = pd.read_pickle(f'{INPUT_ROOT}/{machine}_features.pkl')
    #    else:
    #        ext_data_ = pd.read_pickle(f'{INPUT_ROOT}/{machine}_features.pkl')
    #        ext_data['train']['features'] = np.concatenate([ext_data['train']['features'],
    #                                                        ext_data_['train']['features']], axis=0)
    #        ext_data['train']['labels'] = np.concatenate([ext_data['train']['labels'],
    #                                                     ext_data_['train']['labels']], axis=0)
    #        ext_data['train']['wav_names'] = np.concatenate([ext_data['train']['wav_names'],
    #                                                         ext_data_['train']['wav_names']], axis=0)
            
    #t_d = 3776    # 全特徴量数
    #d = 1024      # 使う特徴量数
    #for phase in ['train', 'valid_source', 'valid_target']:
    #    x = ext_data[phase]['features']
    #    x = random_feature_selection(x)
    #    ext_data[phase]['features'] = x
    #    x = ext_data[phase]['features'][:,512:2048]
    #    ext_data[phase]['features'] = x
    dataloaders_dict = modeler.make_dataloader(ext_data)
    # define writer for tensorbord
    os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    tb_log_dir = TB_DIR + '/' + machine_type
    writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('TRAINING')
    # parameter setting
    in_features = ext_data['features'].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    optimizer = optim.Adam(net.parameters(), lr=1e-3)
    num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.train_net(net, dataloaders_dict, optimizer, num_epochs, writer, model_out_path, score_out_path, pred_out_path)
    
    com.toc()

# %%
machine_types
# Out:
# ['ToyCar', 'gearbox', 'valve', 'ToyTrain', 'pump', 'fan', 'slider']

# %%
#for machine_type in machine_types:
#    run(machine_type)
# Out:
# 2021-05-31 20:58:47,191 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-05-31 20:58:47,192 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-31 20:58:49,297 - 00_train.py - INFO - TRAINING
# 2021-05-31 20:58:51,750 - pytorch_modeler.py - INFO - train
#   0%|          | 0/1105 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 1105/1105 [00:16<00:00, 66.80it/s]
# 2021-05-31 20:59:08,295 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 20:59:08,296 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 20:59:08,383 - pytorch_modeler.py - INFO - epoch:1/30, train_losses:7118.691585,
# 2021-05-31 20:59:08,384 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:16<00:00, 66.88it/s]
# 2021-05-31 20:59:24,908 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 20:59:24,909 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 20:59:25,005 - pytorch_modeler.py - INFO - epoch:2/30, train_losses:702.895587,
# 2021-05-31 20:59:25,006 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:15<00:00, 72.36it/s]
# 2021-05-31 20:59:40,280 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31
- pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:48:13,607 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:48:13,708 - pytorch_modeler.py - INFO - epoch:23/30, train_losses:0.105776,
# 2021-05-31 21:48:13,710 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.42it/s]
# 2021-05-31 21:48:31,999 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:48:32,000 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:48:32,095 - pytorch_modeler.py - INFO - epoch:24/30, train_losses:0.083025,
# 2021-05-31 21:48:32,096 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 59.89it/s]
# 2021-05-31 21:48:50,549 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:48:50,549 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:48:50,644 - pytorch_modeler.py - INFO - epoch:25/30, train_losses:0.069477,
# 2021-05-31 21:48:50,645 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 61.32it/s]
# 2021-05-31 21:49:08,666 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:49:08,667 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:49:08,753 - pytorch_modeler.py - INFO - epoch:26/30, train_losses:0.049270,
# 2021-05-31 21:49:08,754 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 61.73it/s]
# 2021-05-31 21:49:26,655 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:49:26,656 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:49:26,756 - pytorch_modeler.py - INFO - epoch:27/30, train_losses:0.046430,
# 2021-05-31 21:49:26,757 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.96it/s]
# 2021-05-31 21:49:44,886 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:49:44,887 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:49:44,980 - pytorch_modeler.py - INFO - epoch:28/30, train_losses:0.034289,
# 2021-05-31 21:49:44,981 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.22it/s]
# 2021-05-31 21:50:02,741 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:50:02,742 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:50:02,834 - pytorch_modeler.py - INFO - epoch:29/30, train_losses:0.030218,
# 2021-05-31 21:50:02,835 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 63.44it/s]
# 2021-05-31 21:50:20,255 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:50:20,256 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:50:20,355 - pytorch_modeler.py - INFO - epoch:30/30, train_losses:0.026580,
# 2021-05-31 21:50:20,357 - 00_train.py - INFO - TARGET MACHINE_TYPE: slider
# 2021-05-31 21:50:20,357 - 00_train.py - INFO - MAKE DATA_LOADER
# elapsed time: 542.539478064 [sec]
# 2021-05-31 21:50:36,311 - 00_train.py - INFO - TRAINING
# 2021-05-31 21:50:36,345 - pytorch_modeler.py - INFO - train
#   0%|          | 5/1105 [00:00<00:25, 42.31it/s]
# use: cuda:0
# 100%|██████████| 1105/1105 [00:18<00:00, 59.82it/s]
# 2021-05-31 21:50:54,819 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:50:54,820 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:50:54,918 - pytorch_modeler.py - INFO - epoch:1/30, train_losses:8370.220801,
# 2021-05-31 21:50:54,919 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 64.16it/s]
# 2021-05-31 21:51:12,143 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:51:12,144 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:51:12,229 - pytorch_modeler.py - INFO - epoch:2/30, train_losses:1222.728926,
# 2021-05-31 21:51:12,230 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.39it/s]
# 2021-05-31 21:51:29,942 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:51:29,943 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:51:30,035 - pytorch_modeler.py - INFO - epoch:3/30, train_losses:311.816515,
# 2021-05-31 21:51:30,036 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.57it/s]
# 2021-05-31 21:51:47,697 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:51:47,698 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:51:47,792 - pytorch_modeler.py - INFO - epoch:4/30, train_losses:90.618384,
# 2021-05-31 21:51:47,793 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 61.40it/s]
# 2021-05-31 21:52:05,792 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:52:05,792 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:52:05,896 - pytorch_modeler.py - INFO - epoch:5/30, train_losses:30.572411,
# 2021-05-31 21:52:05,897 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.94it/s]
# 2021-05-31 21:52:24,033 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:52:24,034 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:52:24,126 - pytorch_modeler.py - INFO - epoch:6/30, train_losses:12.077743,
# 2021-05-31 21:52:24,127 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 59.93it/s]
# 2021-05-31 21:52:42,569 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:52:42,569 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:52:42,667 - pytorch_modeler.py - INFO - epoch:7/30, train_losses:5.762481,
# 2021-05-31 21:52:42,668 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.18it/s]
# 2021-05-31 21:53:00,440 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:53:00,441 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:53:00,546 - pytorch_modeler.py - INFO - epoch:8/30, train_losses:2.989032,
# 2021-05-31 21:53:00,547 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 61.21it/s]
# 2021-05-31 21:53:18,603 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:53:18,604 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:53:18,708 - pytorch_modeler.py - INFO - epoch:9/30, train_losses:1.569907,
# 2021-05-31 21:53:18,709 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.83it/s]
# 2021-05-31 21:53:36,874 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:53:36,875 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:53:36,962 - pytorch_modeler.py - INFO - epoch:10/30, train_losses:0.840470,
# 2021-05-31 21:53:36,963 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 64.30it/s]
# 2021-05-31 21:53:54,150 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:53:54,151 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:53:54,240 - pytorch_modeler.py - INFO - epoch:11/30, train_losses:0.468333,
# 2021-05-31 21:53:54,241 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:16<00:00, 65.91it/s]
# 2021-05-31 21:54:11,008 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:54:11,009 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:54:11,101 - pytorch_modeler.py - INFO - epoch:12/30, train_losses:0.240661,
# 2021-05-31 21:54:11,102 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:16<00:00, 66.34it/s]
# 2021-05-31 21:54:27,762 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:54:27,763 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:54:27,860 - pytorch_modeler.py - INFO - epoch:13/30, train_losses:0.134720,
# 2021-05-31 21:54:27,861 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 59.84it/s]
# 2021-05-31 21:54:46,328 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:54:46,329 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:54:46,422 - pytorch_modeler.py - INFO - epoch:14/30, train_losses:0.069127,
# 2021-05-31 21:54:46,423 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 63.53it/s]
# 2021-05-31 21:55:03,817 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:55:03,818 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:55:03,916 - pytorch_modeler.py - INFO - epoch:15/30, train_losses:0.033240,
# 2021-05-31 21:55:03,917 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.18it/s]
# 2021-05-31 21:55:21,689 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:55:21,689 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:55:21,781 - pytorch_modeler.py - INFO - epoch:16/30, train_losses:0.019103,
# 2021-05-31 21:55:21,782 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 63.90it/s]
# 2021-05-31 21:55:39,077 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:55:39,078 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:55:39,171 - pytorch_modeler.py - INFO - epoch:17/30, train_losses:0.013627,
# 2021-05-31 21:55:39,172 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 61.13it/s]
# 2021-05-31 21:55:57,251 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:55:57,252 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:55:57,340 - pytorch_modeler.py - INFO - epoch:18/30, train_losses:0.012023,
# 2021-05-31 21:55:57,341 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.24it/s]
# 2021-05-31 21:56:15,098 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:56:15,099 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:56:15,191 - pytorch_modeler.py - INFO - epoch:19/30, train_losses:0.012077,
# 2021-05-31 21:56:15,192 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 64.01it/s]
# 2021-05-31 21:56:32,456 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:56:32,457 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:56:32,552 - pytorch_modeler.py - INFO - epoch:20/30, train_losses:0.011703,
# 2021-05-31 21:56:32,553 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.88it/s]
# 2021-05-31 21:56:50,705 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:56:50,706 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:56:50,796 - pytorch_modeler.py - INFO - epoch:21/30, train_losses:0.011692,
# 2021-05-31 21:56:50,797 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 64.14it/s]
# 2021-05-31 21:57:08,027 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:57:08,028 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:57:08,121 - pytorch_modeler.py - INFO - epoch:22/30, train_losses:0.011878,
# 2021-05-31 21:57:08,122 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 61.62it/s]
# 2021-05-31 21:57:26,055 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:57:26,056 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:57:26,146 - pytorch_modeler.py - INFO - epoch:23/30, train_losses:0.011703,
# 2021-05-31 21:57:26,148 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 63.08it/s]
# 2021-05-31 21:57:43,666 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:57:43,667 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:57:43,774 - pytorch_modeler.py - INFO - epoch:24/30, train_losses:0.011776,
# 2021-05-31 21:57:43,775 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 61.22it/s]
# 2021-05-31 21:58:01,827 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:58:01,828 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:58:01,935 - pytorch_modeler.py - INFO - epoch:25/30, train_losses:0.011678,
# 2021-05-31 21:58:01,937 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 60.81it/s]
# 2021-05-31 21:58:20,111 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:58:20,112 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:58:20,199 - pytorch_modeler.py - INFO - epoch:26/30, train_losses:0.011621,
# 2021-05-31 21:58:20,200 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:18<00:00, 61.13it/s]
# 2021-05-31 21:58:38,279 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:58:38,280 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:58:38,385 - pytorch_modeler.py - INFO - epoch:27/30, train_losses:0.011651,
# 2021-05-31 21:58:38,386 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 63.89it/s]
# 2021-05-31 21:58:55,683 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:58:55,684 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:58:55,773 - pytorch_modeler.py - INFO - epoch:28/30, train_losses:0.011573,
# 2021-05-31 21:58:55,774 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 62.74it/s]
# 2021-05-31 21:59:13,388 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:59:13,388 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:59:13,484 - pytorch_modeler.py - INFO - epoch:29/30, train_losses:0.011654,
# 2021-05-31 21:59:13,485 - pytorch_modeler.py - INFO - train
# 100%|██████████| 1105/1105 [00:17<00:00, 64.25it/s]
# 2021-05-31 21:59:30,685 - pytorch_modeler.py - INFO - valid_source
# 2021-05-31 21:59:30,686 - pytorch_modeler.py - INFO - valid_target
# 2021-05-31 21:59:30,776 - pytorch_modeler.py - INFO - epoch:30/30, train_losses:0.011552,
# elapsed time: 550.419893503 [sec]

# %%
#run(machine_types[2])

# %%
log_file = config['IO_OPTION']['OUTPUT_ROOT']+'/inference_{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_file, 'inference')

# %%
#############################################################################
# run
#############################################################################
def run_inference(machine_type):
    com.tic()
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    ext_data = {}
    ext_data['valid_source'] = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_valid_source_features.pkl')
    ext_data['valid_source']['type'] = com.get_section_types(ext_data['valid_source']['wav_name'])
    
    ext_data['valid_target'] = pd.read_pickle(f'{INPUT_ROOT}/{machine_type}_valid_target_features.pkl')
    ext_data['valid_target']['type'] = com.get_section_types(ext_data['valid_target']['wav_name'])
    
    
    # define writer for tensorbord
    #os.makedirs(TB_DIR+'/'+machine_type, exist_ok=True)
    #tb_log_dir = TB_DIR + '/' + machine_type
    #writer = SummaryWriter(log_dir = tb_log_dir)
    # out path
    model_out_path = MODEL_DIR+'/{}_model.pth'.format(machine_type)
    score_out_path = OUT_SCORE_DIR + '/{}_score.csv'.format(machine_type)
    pred_out_path = OUT_PRED_DIR + '/{}_pred.csv'.format(machine_type)
    logger.info('INFERENCE')
    # parameter setting
    in_features = ext_data['valid_source']['features'][0].shape[1]
    mid_size = config['param']['mid_size']
    latent_size = config['param']['latent_size']
    num_classes = 6
    net = Model(in_features, mid_size, latent_size, num_classes)
    pretrained_dict = torch.load(model_out_path)
    net.load_state_dict(pretrained_dict, strict=True)
    #optimizer = optim.Adam(net.parameters(), lr=1e-3)
    #num_epochs = config['param']['num_epochs']
    #scheduler = optim.lr_scheduler.OneCycleLR(optimizer=optimizer, pct_start=0.1, div_factor=1e-2, 
    #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
    # training
    output_dicts = modeler.inference_net(net, ext_data, score_out_path, pred_out_path)
    
    com.toc()

# %%
for machine_type in machine_types:
    run_inference(machine_type)
# Out:
# 2021-05-31 22:19:03,344 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-05-31 22:19:03,346 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-31 22:19:04,908 - 00_train.py - INFO - INFERENCE
# 2021-05-31 22:19:07,720 - pytorch_modeler.py - INFO - valid_source
#   0%|          | 0/4 [00:00<?, ?it/s]
# use: cuda:0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8b33557f550b> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run_inference(machine_type)
#
# <ipython-input-19-4001b4a1d435> in run_inference(machine_type)
#      36     #                                          max_lr=1e-3, epochs=num_epochs, steps_per_epoch=len(dataloaders_dict['train']))
#      37     # training
# ---> 38     output_dicts = modeler.inference_net(net, ext_data, score_out_path, pred_out_path)
#      39
#      40     com.toc()
#
# ~/research/dcase2021_task2/src/model_codes/CenterLossVAE/MahalanobisAD_subseq_3_ex15/pytorch_modeler.py in inference_net(net, ext_data, score_out_path, pred_out_path)
#     311                 with torch.no_grad():
#     312                     # model
# --> 313                     output_dict = net(input, section_type, device)
#     314                     # calc loss
#     315                     reconst_error = output_dict['reconst_error']
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# TypeError: forward() missing 1 required positional argument: 'device'

# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter

#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from pytorch_model import ResNet38 as Model
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('FEATURE EXTRACTION')
    net = Model(sample_rate=config['param']['sample_rate'],
                window_size=config['param']['window_size'],
                hop_size=config['param']['hop_size'],
                mel_bins=config['param']['mel_bins'],
                fmin=config['param']['fmin'],
                fmax=config['param']['fmax'])
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])
    net.load_state_dict(pretrained_dict['model'], strict=False)
    output_dicts = modeler.extract_net(net, dataloaders_dict)
    out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    pd.to_pickle(output_dicts, out_path)
    logger.info(f'SAVE SUCCESS : {out_path}')
    
    com.toc()

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
for machine_type in machine_types:
    run(machine_type, dev_paths)
# Out:
# 2021-03-30 22:25:19,362 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-03-30 22:25:19,363 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:25:19,363 - 00_train.py - INFO - FEATURE EXTRACTION
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:46<00:00,  1.95s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.32s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.33s/it]
# 2021-03-30 22:26:32,757 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/fan_features.pkl
# 2021-03-30 22:26:32,760 - 00_train.py - INFO - TARGET MACHINE_TYPE: gearbox
# 2021-03-30 22:26:32,761 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:26:32,762 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 73.396582842 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:44<00:00,  1.87s/it]
# 100%|██████████| 6/6 [00:13<00:00,  2.19s/it]
# 100%|██████████| 6/6 [00:11<00:00,  1.97s/it]
# 2021-03-30 22:27:44,320 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/gearbox_features.pkl
# 2021-03-30 22:27:44,322 - 00_train.py - INFO - TARGET MACHINE_TYPE: pump
# 2021-03-30 22:27:44,323 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:27:44,324 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 71.560665131 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:41<00:00,  1.74s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.88s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.19s/it]
# 2021-03-30 22:28:48,046 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/pump_features.pkl
# 2021-03-30 22:28:48,049 - 00_train.py - INFO - TARGET MACHINE_TYPE: slider
# 2021-03-30 22:28:48,049 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:28:48,050 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 63.725076675 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:46<00:00,  1.93s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.32s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.33s/it]
# 2021-03-30 22:29:59,150 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/slider_features.pkl
# 2021-03-30 22:29:59,163 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyCar
# 2021-03-30 22:29:59,164 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:29:59,165 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 71.112843513 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:47<00:00,  1.99s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.20s/it]
# 100%|██████████| 5/5 [00:11<00:00,  2.30s/it]
# 2021-03-30 22:31:11,074 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/ToyCar_features.pkl
# 2021-03-30 22:31:11,077 - 00_train.py - INFO - TARGET MACHINE_TYPE: ToyTrain
# 2021-03-30 22:31:11,077 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:31:11,078 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 71.912078857 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:44<00:00,  1.87s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.98s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.05s/it]
# 2021-03-30 22:32:17,694 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/ToyTrain_features.pkl
# 2021-03-30 22:32:17,702 - 00_train.py - INFO - TARGET MACHINE_TYPE: valve
# 2021-03-30 22:32:17,703 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-03-30 22:32:17,704 - 00_train.py - INFO - FEATURE EXTRACTION
# elapsed time: 66.623746395 [sec]
#   0%|          | 0/24 [00:00<?, ?it/s]
# use: cuda:0
# 100%|██████████| 24/24 [00:43<00:00,  1.81s/it]
# 100%|██████████| 5/5 [00:10<00:00,  2.03s/it]
# 100%|██████████| 5/5 [00:09<00:00,  1.95s/it]
# 2021-03-30 22:33:22,642 - 00_train.py - INFO - SAVE SUCCESS : /media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_res_sr32k_hyperalignment/extraction_features/valve_features.pkl
# elapsed time: 64.940412521 [sec]

# %%
machine_type = 'pump'
input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
ext_data = pd.read_pickle(input_path)

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['valid_source']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %% [markdown]
# history = run('ToyCar')
# with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#     pickle.dump(history , file)

# %%
print(M_means.shape)
plt.imshow(M_means, aspect='auto', cmap='jet')
plt.title(phase)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-26c2d8c719c5> in <module>
# ----> 1 print(M_means.shape)
#       2 plt.imshow(M_means, aspect='auto', cmap='jet')
#       3 plt.title(phase)
#       4 plt.colorbar()
#       5 plt.show()
#
# NameError: name 'M_means' is not defined

# %%
import yaml
yaml.warnings({'YAMLLoadWarning': False})
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']

# %% [markdown]
# # load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# ML lib
from scipy.stats import zscore
from umap import UMAP
from sklearn.mixture import GaussianMixture
from sklearn.covariance import LedoitWolf
from scipy.spatial.distance import mahalanobis


import librosa
import IPython
import librosa.display

# %% [markdown]
# # load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# # Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_orig_add_data/config.yaml'

# %% [markdown]
# # load data

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
data_types = ['train', 'valid_source', 'valid_target']

# %%
def load_ext_data(machine_type):
    input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    ext_data = pd.read_pickle(input_path)
    
    return ext_data

# %% [raw]
# machine_type = 'pump'
# input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
# ext_data = pd.read_pickle(input_path)
#
#
# data_type = data_types[0]
# feats = ext_data[data_type]['features']
# labels = ext_data[data_type]['labels']
# data_types = [data_type] * len(ext_data[data_type]['labels'])

# %% [raw]
# for i, data_type in enumerate(data_types):
#     if i == 0:
#         feats = ext_data[data_type]['features']
#         labels = ext_data[data_type]['labels']
#         data_types = [data_type] * len(ext_data[data_type]['labels'])
#     else:
#         feats = np.concatenate([feats, ext_data[data_type]['features']], axis=0)
#         labels = np.concatenate([labels, ext_data[data_type]['labels']], axis=0)
#         # data type
#         data_type = [data_type] * len(ext_data[data_type]['labels'])
#         data_types = data_types + data_type

# %% [raw]
# wav_names = []
# for wav_name in ext_data[data_type]['wav_names']:
#     wav_names += wav_name

# %% [raw]
# len(wav_names)

# %%
def get_section_types(wav_names):
    section_types = []
    for wav_name in wav_names:
        if 'section_00' in wav_name:
            section_types.append(0)
        elif 'section_01' in wav_name:
            section_types.append(1)
        elif 'section_02' in wav_name:
            section_types.append(2)
        elif 'section_03' in wav_name:
            section_types.append(3)
        elif 'section_04' in wav_name:
            section_types.append(4)
        else:
            section_types.append(5)
    
    return section_types

# %%
def get_target_names(wav_names):
    target_names = []
    for wav_name in wav_names:
        if 'target' in wav_name:
            target_names.append(wav_name)
    
    return target_names

# %%
target_names = get_target_names(wav_names)

# %%
target_names
# Out:
# ['/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_target_train_normal_0000_pattern_02_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_target_train_normal_0001_pattern_02_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_target_train_normal_0002_pattern_03_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_01_target_train_normal_0000_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_01_target_train_normal_0001_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_01_target_train_normal_0002_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_02_target_train_normal_0000_pattern_00_air_pump_comb.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_02_target_train_normal_0001_pattern_00_air_pump_comb.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_02_target_train_normal_0002_pattern_01_air_pump_comb.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_03_target_train_normal_0000_pattern_04_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_03_target_train_normal_0001_pattern_05_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_03_target_train_normal_0002_pattern_04_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_04_target_train_normal_0000_pattern_01_water_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_04_target_train_normal_0001_pattern_00_water_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_04_target_train_normal_0002_pattern_00_water_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_05_target_train_normal_0000_pattern_01_air_pump_comb.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_05_target_train_normal_0001_pattern_00_air_pump_comb.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/valve/train/section_05_target_train_normal_0002_pattern_00_air_pump_comb.wav']

# %%
wav_names = ext_data['train']['wav_names']
section_types = get_section_types(wav_names)

# %%
wav_names
# Out:
# ['/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0000_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0001_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0002_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0003_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_
pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0896_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0897_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0898_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0899_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0900_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0901_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0902_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0903_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0904_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0905_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0906_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0907_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0908_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0909_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0910_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0911_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0912_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0913_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0914_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0915_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0916_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0917_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0918_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0919_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0920_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0921_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0922_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0923_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0924_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0925_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0926_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0927_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0928_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0929_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0930_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0931_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0932_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0933_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0934_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0935_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0936_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0937_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0938_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0939_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0940_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0941_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0942_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0943_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0944_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0945_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0946_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0947_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0948_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0949_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0950_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0951_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0952_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0953_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0954_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0955_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0956_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0957_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0958_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0959_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0960_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0961_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0962_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0963_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0964_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0965_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0966_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0967_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0968_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0969_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0970_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0971_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0972_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0973_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0974_pattern_00_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0975_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0976_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0977_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0978_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0979_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0980_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0981_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0982_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0983_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0984_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0985_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0986_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0987_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0988_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0989_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0990_pattern_01_no_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0991_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0992_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0993_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0994_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0995_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0996_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0997_pattern_01_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0998_pattern_00_air_pump.wav',
#  '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/dev_data/valve/train/section_00_source_train_normal_0999_pattern_00_air_pump.wav',
#  ...]

# %% [markdown]
# # evaluation

# %% [markdown]
# ## calc MVG (multivariate Gaussian)

# %%
com.tic()

MVG = {}
for machine_type in machine_types:
    MVG[machine_type] = {}
    ext_data = load_ext_data(machine_type)
    
    mean = ext_data['train']['features'].mean(axis=0)
    cov_estimator = LedoitWolf()
    cov_estimator.fit(ext_data['train']['features'])
    cov = cov_estimator.covariance_
    MVG[machine_type]['mean'] = mean
    MVG[machine_type]['cov'] = cov

com.toc()
# Out:
# elapsed time: 33.230638504 [sec]

# %%
MVG[machine_type]['cov'].shape
# Out:
# (3072, 3072)

# %% [markdown]
# ## estimate

# %%
for machine_type in machine_types:
    # get MVG
    mean = MVG[machine_type]['mean']
    cov_inv = np.linalg.inv(MVG[machine_type]['cov'])
    # load data
    ext_data = load_ext_data(machine_type)
    # calc mahalanobis (Anomaly Score)
    valid_source_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_source']['features']]
    valid_target_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_target']['features']]
    # np.array
    valid_source_dists = np.array(valid_source_dists)
    valid_target_dists = np.array(valid_target_dists)
    # calc AUC
    roc_auc = roc_auc_score(ext_data['valid_source']['labels'], valid_source_dists)
    logger.info(f'{machine_type} valid_source AUC : {roc_auc}')
    roc_auc = roc_auc_score(ext_data['valid_target']['labels'], valid_target_dists)
    logger.info(f'{machine_type} valid_target AUC : {roc_auc}')
    
    plt.figure(figsize=(20,3))
    plt.title(f'Source {machine_type}')
    plt.plot(valid_source_dists, label='Anomaly Score')
    plt.plot(ext_data['valid_source']['labels'], label='Ground Truth')
    plt.legend()
    plt.show()
    
    plt.figure(figsize=(20,3))
    plt.title(f'Target {machine_type}')
    plt.plot(valid_target_dists, label='Anomaly Score')
    plt.plot(ext_data['valid_target']['labels'], label='Ground Truth')
    plt.legend()
    plt.show()
# Out:
# 2021-04-06 19:26:41,149 - 00_train.py - INFO - fan valid_source AUC : 0.5352333333333333
# 2021-04-06 19:26:41,151 - 00_train.py - INFO - fan valid_target AUC : 0.5821111111111111
# 2021-04-06 19:26:45,726 - 00_train.py - INFO - gearbox valid_source AUC : 0.5902288213723736
# 2021-04-06 19:26:45,730 - 00_train.py - INFO - gearbox valid_target AUC : 0.6468157651410078
# 2021-04-06 19:26:49,467 - 00_train.py - INFO - pump valid_source AUC : 0.5599555555555555
# 2021-04-06 19:26:49,471 - 00_train.py - INFO - pump valid_target AUC : 0.5293
# 2021-04-06 19:26:53,011 - 00_train.py - INFO - slider valid_source AUC : 0.6155201879940184
# 2021-04-06 19:26:53,014 - 00_train.py - INFO - slider valid_target AUC : 0.6211810154525386
# 2021-04-06 19:26:56,376 - 00_train.py - INFO - ToyCar valid_source AUC : 0.5893444444444446
# 2021-04-06 19:26:56,378 - 00_train.py - INFO - ToyCar valid_target AUC : 0.5296222222222222
# 2021-04-06 19:26:59,799 - 00_train.py - INFO - ToyTrain valid_source AUC : 0.48385555555555554
# 2021-04-06 19:26:59,802 - 00_train.py - INFO - ToyTrain valid_target AUC : 0.5021777777777778
# 2021-04-06 19:27:03,141 - 00_train.py - INFO - valve valid_source AUC : 0.5240444444444444
# 2021-04-06 19:27:03,143 - 00_train.py - INFO - valve valid_target AUC : 0.5445888888888889

# %% [markdown]
# ## calc GMM

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
ext_data = load_ext_data(machine_types[6])
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(ext_data['train']['features'])
# Out:
# GaussianMixture(n_components=3, random_state=42)

# %%
gmm.bic(ext_data['train']['features'])
# Out:
# 3319258.8933906704

# %%
pred = gmm.predict(ext_data['train']['features'])

# %%
plt.hist(pred)
# Out:
# (array([ 790.,    0.,    0.,    0.,    0.,  378.,    0.,    0.,    0.,
#         1841.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
gmm_covs = gmm.covariances_
gmm_means = gmm.means_

# %%
gmm_covs = gmm.covariances_
gmm_means = gmm.means_


# calc mahalanobis (Anomaly Score)
valid_source_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_source']['features']]
valid_target_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_target']['features']]

# %%
for machine_type in machine_types:
    # get MVG
    mean = MVG[machine_type]['mean']
    cov_inv = MVG[machine_type]['cov']
    # load data
    ext_data = load_ext_data(machine_type)
    # calc mahalanobis (Anomaly Score)
    valid_source_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_source']['features']]
    valid_target_dists = [mahalanobis(sample, mean, cov_inv) for sample in ext_data['valid_target']['features']]
    # np.array
    valid_source_dists = np.array(valid_source_dists)
    valid_target_dists = np.array(valid_target_dists)
    # calc AUC
    roc_auc = roc_auc_score(ext_data['valid_source']['labels'], valid_source_dists)
    logger.info(f'{machine_type} valid_source AUC : {roc_auc}')
    roc_auc = roc_auc_score(ext_data['valid_target']['labels'], valid_target_dists)
    logger.info(f'{machine_type} valid_target AUC : {roc_auc}')

# %%
gmm_section_types = gmm.predict(feats)

# %%
sns.distplot(section_types)
# Out:
# /home/hiroki/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(gmm_section_types)

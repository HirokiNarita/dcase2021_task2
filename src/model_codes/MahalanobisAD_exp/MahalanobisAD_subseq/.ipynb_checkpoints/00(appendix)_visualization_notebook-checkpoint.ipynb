# %%
import yaml
yaml.warnings({'YAMLLoadWarning': False})
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']

# %% [markdown]
# # load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

from scipy.stats import zscore
from umap import UMAP
import umap

import librosa
import IPython
import librosa.display

# %% [markdown]
# # load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# # Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/MahalanobisAD_torchvison_resnet18/config.yaml'

# %% [markdown]
# # load data

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %%
machine_type = 'pump'
input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
ext_data = pd.read_pickle(input_path)

# %%
data_types = ['train', 'valid_source', 'valid_target']

# %% [raw]
# for i, data_type in enumerate(data_types):
#     if i == 0:
#         feats = ext_data[data_type]['features']
#         labels = ext_data[data_type]['labels']
#         data_types = [data_type] * len(ext_data[data_type]['labels'])
#     else:
#         feats = np.concatenate([feats, ext_data[data_type]['features']], axis=0)
#         labels = np.concatenate([labels, ext_data[data_type]['labels']], axis=0)
#         # data type
#         data_type = [data_type] * len(ext_data[data_type]['labels'])
#         data_types = data_types + data_type

# %%
data_type = data_types[0]

feats = ext_data[data_type]['features']
labels = ext_data[data_type]['labels']
data_types = [data_type] * len(ext_data[data_type]['labels'])

# %%
wav_names = []
for wav_name in ext_data[data_type]['wav_names']:
    wav_names += wav_name

# %%
len(wav_names)
# Out:
# 800484

# %%
def get_section_types(wav_names):
    section_types = []
    for wav_name in wav_names:
        if 'section_00' in wav_name:
            section_types.append(0)
        elif 'section_01' in wav_name:
            section_types.append(1)
        else:
            section_types.append(2)
    
    return section_types

section_types = get_section_types(wav_names)

# %% [markdown]
# # Describe

# %%
#pd.set_option('display.max_columns', 5000)
#feat_df.describe()

# %%
pd.set_option('display.max_columns', 50)

# %%
corrmat = pd.DataFrame(np.corrcoef(feats.T))
# Out:
# /home/hiroki/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/hiroki/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
plt.figure(figsize=(15,15))
cmap = plt.cm.jet
cmap.set_bad("k",1.)
plt.imshow(corrmat, aspect='auto', cmap=cmap)
plt.title('correlation matrix')
plt.colorbar()
# Out:
# <ipython-input-17-e9ff5c3bdb10>:3: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("jet"))
#   cmap.set_bad("k",1.)

# %% [markdown]
# # umap

# %%
feats.shape
# Out:
# (6018, 1920)

# %%
from sklearn.feature_selection import VarianceThreshold

vt = VarianceThreshold(threshold=0)
new_feats = vt.fit_transform(feats)

# %%
new_feats.shape
# Out:
# (6018, 1876)

# %%
# %%time
mapper = UMAP(n_components=2, random_state=42, n_neighbors=15)
embedding = mapper.fit_transform(feats)
# Out:
# CPU times: user 15.3 s, sys: 167 ms, total: 15.4 s
# Wall time: 12.4 s

# %%
embedding.shape
# Out:
# (6018, 2)

# %%
#import umap.plot

# %%
plt.figure(figsize=(10,10))
plt.title('UMAP')

embedding_x = embedding[:, 0]
embedding_y = embedding[:, 1]
for n in np.unique(section_types):
    plt.scatter(embedding_x[section_types == n],
                embedding_y[section_types == n],
                label=n)
plt.grid()
plt.legend(title='Section')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-86e74a6bb868> in <module>
#       5 embedding_y = embedding[:, 1]
#       6 for n in np.unique(section_types):
# ----> 7     plt.scatter(embedding_x[section_types == n],
#       8                 embedding_y[section_types == n],
#       9                 label=n)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 6018 but corresponding boolean dimension is 800484

# %%
# %%time
mapper = UMAP(n_components=2, random_state=42, n_neighbors=15, densmap=True)
embedding = mapper.fit_transform(feats)
# Out:
# CPU times: user 20 s, sys: 91.9 ms, total: 20.1 s
# Wall time: 18.7 s

# %%
plt.figure(figsize=(10,10))
plt.title('UMAP')

embedding_x = embedding[:, 0]
embedding_y = embedding[:, 1]
for n in np.unique(section_types):
    plt.scatter(embedding_x[section_types == n],
                embedding_y[section_types == n],
                label=n)
plt.grid()
plt.legend(title='Section')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('UMAP')

embedding_x = embedding[:, 0]
embedding_y = embedding[:, 1]
for n in np.unique(section_types):
    plt.scatter(embedding_x[section_types == n],
                embedding_y[section_types == n],
                label=n)
plt.grid()
plt.legend(title='Section')
plt.show()

# %%
mapper.
# Out:
# False

# %% [raw]
# X = embedding[:, 0] #自然数の配列
# Y = embedding[:, 1] #特に意味のない正弦
# Z = embedding[:, 2] #特に意味のない自然対数
# #備考：Numpyだとnp.log()は自然対数。常用対数はnp.log10()
#
# #seabornでグラフをきれいにしたいだけのコード
# sns.set_style("darkgrid")
#
# #3次元プロットするためのモジュール
# from mpl_toolkits.mplot3d import Axes3D
#
# #グラフの枠を作っていく
# fig = plt.figure()
# ax = Axes3D(fig)
#
# #軸にラベルを付けたいときは書く
# ax.set_xlabel("X")
# ax.set_ylabel("Y")
# ax.set_zlabel("Z")
#
# #.plotで描画
# #linestyle='None'にしないと初期値では線が引かれるが、3次元の散布図だと大抵ジャマになる
# #markerは無難に丸
# ax.plot(X,Y,Z,marker="o",linestyle='None', label)
#
# #最後に.show()を書いてグラフ表示
# plt.show()

# %% [markdown]
# # GMM

# %%
from sklearn.mixture import GaussianMixture

# %%
gmm = GaussianMixture(n_components=3, random_state=42)
gmm.fit(feats)
# Out:
# GaussianMixture(n_components=3, random_state=42)

# %%
gmm_section_types = gmm.predict(feats)

# %%
sns.distplot(section_types)
# Out:
# /home/hiroki/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(gmm_section_types)

# %% [markdown]
# # train

# %%
import yaml
import os

with open("./config.yaml", 'rb') as f:
    config = yaml.load(f)
# Out:
# <ipython-input-1-1499ab5789c7>:5: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(f)

# %%
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
os.makedirs(OUTPUT_ROOT, exist_ok=True)

# %% [markdown]
# ## load library

# %%
# python default library
import os
import shutil
import datetime
import sys
import pickle

# general analysis tool-kit
import numpy as np
import pandas as pd
#from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# pytorch
import torch
from torch import optim, nn
from torch.utils.tensorboard import SummaryWriter
#from torchsummary import summary

# etc
import yaml
yaml.warnings({'YAMLLoadWarning': False})

# original library
sys.path.append('/home/hiroki/research/dcase2021_task2/src/functions')
import common as com
import pytorch_modeler as modeler
from models import Wavegram_Cnn14
#from pytorch_utils import filtered_load_model
#import models

import librosa
import IPython
import librosa.display

# %% [markdown]
# ## load config and set logger

# %%
log_folder = config['IO_OPTION']['OUTPUT_ROOT']+'/{0}.log'.format(datetime.date.today())
logger = com.setup_logger(log_folder, '00_train.py')

# %% [markdown]
# ## Setting

# %%
# Setting seed
modeler.set_seed(42)

# %%
############################################################################
# Setting I/O path
############################################################################
# input dirs
INPUT_ROOT = config['IO_OPTION']['INPUT_ROOT']
dev_dir = INPUT_ROOT + "/dev_data"
add_dev_dir = INPUT_ROOT + "/add_dev_data"
# machine type
machine_types = os.listdir(dev_dir)
# output dirs
OUTPUT_ROOT = config['IO_OPTION']['OUTPUT_ROOT']
MODEL_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/models'
TB_DIR = config['IO_OPTION']['OUTPUT_ROOT'] + '/tb'
OUT_FEATURE_DIR = OUTPUT_ROOT + '/extraction_features'
#os.makedirs(OUTPUT_ROOT, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(TB_DIR, exist_ok=True)
os.makedirs(OUT_FEATURE_DIR, exist_ok=True)
# copy config
shutil.copy('./config.yaml', OUTPUT_ROOT)
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/output/PANNs_wavegram/config.yaml'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ## make path list

# %% [markdown]
# - __train_paths__ ([dict]): Each Machine Type
#     - __ToyCar__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) :paths
#     - __ToyTrain__ ([dict]): Each dataset
#         - train ([list]) : paths
#         - valid_source ([list]) : paths
#         - valid_target ([list]) : paths
#     - ...

# %%
dev_paths = {}

for machine_type in machine_types:
    # dev train
    dev_train_paths = [f"{dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/train")]
    dev_train_paths = sorted(dev_train_paths)
    
    # add_dev train
    add_dev_paths = [f"{add_dev_dir}/{machine_type}/train/" + file for file in os.listdir(f"{add_dev_dir}/{machine_type}/train")]
    add_dev_paths = sorted(add_dev_paths)
    
    # dev_source valid
    dev_source_paths = [f"{dev_dir}/{machine_type}/source_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/source_test")]
    dev_source_paths = sorted(dev_source_paths)
    
    # dev_target valid
    dev_target_paths = [f"{dev_dir}/{machine_type}/target_test/" + file for file in os.listdir(f"{dev_dir}/{machine_type}/target_test")]
    dev_target_paths = sorted(dev_target_paths)
    
    # bundle
    dev_paths[machine_type] = {}
    dev_paths[machine_type]['train'] = dev_train_paths + add_dev_paths
    dev_paths[machine_type]['valid_source'] = dev_source_paths
    dev_paths[machine_type]['valid_target'] = dev_target_paths

# %%
dev_paths['fan']['train'][-1]
# Out:
# '/media/hiroki/HDD1TB/research/dcase2021_task2/datasets/add_dev_data/fan/train/section_05_target_train_normal_0002_strength_1_temp_max.wav'

# %%
# net = Wavegram_Cnn14(sample_rate=config['param']['sample_rate'],
#                      window_size=config['param']['window_size'],
#                      hop_size=config['param']['hop_size'],
#                      mel_bins=config['param']['mel_bins'],
#                      fmin=config['param']['fmin'],
#                      fmax=config['param']['fmax'],
#                      classes_num=527)
# pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])

# %%
#pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])

# %%
#net.load_state_dict(pretrained_dict['model'], strict=True)
# Out:
# <All keys matched successfully>

# %%
#net.conv_block6
# Out:
# ConvBlock(
#   (conv1): Conv2d(1024, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ## training

# %%
#############################################################################
# run
#############################################################################
def run(machine_type, dev_paths):
    com.tic()
    
    logger.info('TARGET MACHINE_TYPE: {0}'.format(machine_type))
    logger.info('MAKE DATA_LOADER')
    # dev_train_paths
    dataloaders_dict = modeler.make_dataloader(dev_paths, machine_type)
    # parameter setting
    logger.info('FEATURE EXTRACTION')
    net = Wavegram_Cnn14(sample_rate=config['param']['sample_rate'],
                         window_size=config['param']['window_size'],
                         hop_size=config['param']['hop_size'],
                         mel_bins=config['param']['mel_bins'],
                         fmin=config['param']['fmin'],
                         fmax=config['param']['fmax'],
                         classes_num=527)
    pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])
    net.load_state_dict(pretrained_dict['model'], strict=True)
    output_dicts = modeler.extract_net(net, dataloaders_dict)
    out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
    pd.to_pickle(output_dicts, out_path)
    logger.info(f'SAVE SUCCESS : {out_path}')
    
    com.toc()

# %%
machine_types
# Out:
# ['fan', 'gearbox', 'pump', 'slider', 'ToyCar', 'ToyTrain', 'valve']

# %% [markdown]
# # run

# %%
for machine_type in machine_types:
    run(machine_type, dev_paths)
# Out:
# 2021-05-29 12:59:23,600 - 00_train.py - INFO - TARGET MACHINE_TYPE: fan
# 2021-05-29 12:59:23,601 - 00_train.py - INFO - MAKE DATA_LOADER
# 2021-05-29 12:59:23,602 - 00_train.py - INFO - FEATURE EXTRACTION
#   0%|          | 0/48 [00:00<?, ?it/s]
# use: cuda:0
#   0%|          | 0/48 [00:05<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-2349e03e993b> in <module>
#       1 for machine_type in machine_types:
# ----> 2     run(machine_type, dev_paths)
#
# <ipython-input-15-008a2ee48a2d> in run(machine_type, dev_paths)
#      20     pretrained_dict = torch.load(config['IO_OPTION']['PREMODEL_ROOT'])
#      21     net.load_state_dict(pretrained_dict['model'], strict=True)
# ---> 22     output_dicts = modeler.extract_net(net, dataloaders_dict)
#      23     out_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
#      24     pd.to_pickle(output_dicts, out_path)
#
# ~/research/dcase2021_task2/src/model_codes/MahalanobisAD_exp/PANNs_wavegram/pytorch_modeler.py in extract_net(net, dataloaders_dict)
#     148
#     149             with torch.no_grad():
# --> 150                 _ = net(input, device)  # (batch_size,input(2D))
#     151                 outputs = torch.cat(outputs, dim=1).cpu()
#     152                 M_means.append(outputs)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/MahalanobisAD_exp/PANNs_wavegram/models.py in forward(self, input, mixup_lambda)
#    2279         # Wavegram
#    2280         a1 = F.relu_(self.pre_bn0(self.pre_conv0(input[:, None, :])))
# -> 2281         a1 = self.pre_block1(a1, pool_size=4)
#    2282         a1 = self.pre_block2(a1, pool_size=4)
#    2283         a1 = self.pre_block3(a1, pool_size=4)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/research/dcase2021_task2/src/model_codes/MahalanobisAD_exp/PANNs_wavegram/models.py in forward(self, input, pool_size)
#    2218
#    2219         x = input
# -> 2220         x = F.relu_(self.bn1(self.conv1(x)))
#    2221         x = F.relu_(self.bn2(self.conv2(x)))
#    2222         x = F.max_pool1d(x, kernel_size=pool_size)
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     133         assert self.running_mean is None or isinstance(self.running_mean, torch.Tensor)
#     134         assert self.running_var is None or isinstance(self.running_var, torch.Tensor)
# --> 135         return F.batch_norm(
#     136             input,
#     137             # If buffers are not to be tracked, ensure that they won't be updated
#
# ~/anaconda3/envs/dcase2021_task2/lib/python3.8/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2147         _verify_batch_size(input.size())
#    2148
# -> 2149     return torch.batch_norm(
#    2150         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2151     )
#
# RuntimeError: CUDA out of memory. Tried to allocate 1.95 GiB (GPU 0; 11.77 GiB total capacity; 5.04 GiB already allocated; 1.80 GiB free; 5.06 GiB reserved in total by PyTorch)

# %%
machine_type = 'pump'
input_path = f'{OUT_FEATURE_DIR}/{machine_type}_features.pkl'
ext_data = pd.read_pickle(input_path)

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['valid_source']['features'], cmap='jet')
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
plt.imshow(ext_data['train']['features'], cmap='jet')
plt.colorbar()

# %% [markdown]
# history = run('ToyCar')
# with open('{}/{}_history.pkl'.format(PKL_DIR, machine_type), 'wb') as file:
#     pickle.dump(history , file)

# %%
print(M_means.shape)
plt.imshow(M_means, aspect='auto', cmap='jet')
plt.title(phase)
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-26c2d8c719c5> in <module>
# ----> 1 print(M_means.shape)
#       2 plt.imshow(M_means, aspect='auto', cmap='jet')
#       3 plt.title(phase)
#       4 plt.colorbar()
#       5 plt.show()
#
# NameError: name 'M_means' is not defined
